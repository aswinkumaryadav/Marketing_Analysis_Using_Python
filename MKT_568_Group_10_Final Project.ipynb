# %% [markdown]
# # **Importing Libraries and Loading the Dataset**

# %%
# Importing necessary libraries for data analysis and visualization
import pandas as pd                      # For data manipulation and analysis
import matplotlib.pyplot as plt          # For data visualization
import numpy as np                       # For numerical operations
import seaborn as sns                    # For enhanced data visualization
from scipy.stats import zscore           # For calculating Z-scores
import statsmodels.api as sm             # For regression modeling
from statsmodels.stats.outliers_influence import variance_inflation_factor  # For calculating VIF
from statsmodels.tools.tools import add_constant  # To add intercept term for regression
import re                                # For regular expression operations

# %%
# Load the Instagram dataset from an Excel file
data=pd.read_excel('instagram_data.xlsx')

# %%
# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#      USERNAME  FOLLOWERS  FOLLOWING  LIKES  COMMENTS  \
# 0  georgiou82    1134619        915  18560        95
# 1  georgiou82    1134619        915  17710        86
# 2  georgiou82    1134619        915  11959        79
# 3  georgiou82    1134619        915  13608        37
# 4  georgiou82    1134619        915  15842        62
#
#                                                 TEXT                DATE  \
# 0  Every day is a #newday and every experience is... 2017-02-11 11:05:10
# 1  #goodnight !!! The #weekend is ahead!!! Have a... 2017-02-11 00:33:10
# 2  #tb #2007 #stous31dromous #megatv #greece #new... 2017-02-09 15:51:47
# 3  Cold weather brings people together.... #filmi... 2017-02-08 18:21:57
# 4  The youngest hearts might be the oldest souls.... 2017-02-08 13:03:14
#
#    TYPE(1 PHOTO,2 VIDEO) USERS IN PHOTO  \
# 0                      1              1
# 1                      1              1
# 2                      1              3
# 3                      1              3
# 4                      1              0
#
#                                       LINK  \
# 0  https://www.instagram.com/p/BQXZpSQjiPj
# 1  https://www.instagram.com/p/BQWRUV6j8b-
# 2  https://www.instagram.com/p/BQSw2wMj0Bw
# 3  https://www.instagram.com/p/BQQdPrLDeRz
# 4  https://www.instagram.com/p/BQP4xY7jAXb
#
#                                         list_of_tags  number_of_tags  \
# 0                                    #newday #newera               2
# 1                       #goodnight #weekend #goodone               3
# 2  #tb #2007 #stous31dromous #megatv #greece #new...               7
# 3                                #filming #mprousko4               2
# 4            #lifelessons #andreasgeorgiou #tb #peru               4
#
#       list_of_mentions  number_of_mentions
# 0                  NaN                   0
# 1                  NaN                   0
# 2                  NaN                   0
# 3  @stamosts @kinolis2                   2
# 4                  NaN                   0

# %%
# Display the last few rows of the dataset to understand its structure
data.tail()
# Out:
#         USERNAME  FOLLOWERS  FOLLOWING  LIKES  COMMENTS  \
# 19676  kourtideo      17993       7501    615         0
# 19677  kourtideo      17993       7501    505         0
# 19678  kourtideo      17993       7501    829         0
# 19679  kourtideo      17993       7501    660         1
# 19680  kourtideo      17993       7501    598         0
#
#                                                     TEXT                DATE  \
# 19676          Earlier today ???❤️ \| #ktima #nisis #top 2017-04-22 23:28:29
# 19677                   ☕️?? \| #Sunday #relax #espresso 2017-04-23 20:36:10
# 19678  That's what is about ??☀️?? \| #nammos #mykono... 2017-04-24 18:42:39
# 19679  Relaxing after work ☕️☀️? \| #coffee #sourtouk... 2017-04-25 17:01:32
# 19680               ?☀️?? \| #lake #ippokrateiospoliteia 2017-04-26 19:05:23
#
#        TYPE(1 PHOTO,2 VIDEO) USERS IN PHOTO  \
# 19676                      1              -
# 19677                      1              -
# 19678                      1              -
# 19679                      1              -
# 19680                      1              -
#
#                                            LINK  \
# 19676  https://www.instagram.com/p/BTM3fOADPxz/
# 19677  https://www.instagram.com/p/BTPIkBQDbnt/
# 19678  https://www.instagram.com/p/BTRgXe2DA4z/
# 19679  https://www.instagram.com/p/BTT5lykj_UD/
# 19680  https://www.instagram.com/p/BTWsjzXj0M4/
#
#                                       list_of_tags  number_of_tags  \
# 19676                           #ktima #nisis #top               3
# 19677                     #Sunday #relax #espresso               3
# 19678  #nammos #mykonos #summer #loading #Kourtour               5
# 19679             #coffee #sourtouki #glyfada #ark               4
# 19680                  #lake #ippokrateiospoliteia               2
#
#       list_of_mentions  number_of_mentions
# 19676              NaN                   0
# 19677              NaN                   0
# 19678              NaN                   0
# 19679              NaN                   0
# 19680              NaN                   0

# %%
# Display the basic information about the dataset, including data types and non-null counts
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19681 entries, 0 to 19680
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   USERNAME               19681 non-null  object
#  1   FOLLOWERS              19681 non-null  int64
#  2   FOLLOWING              19681 non-null  int64
#  3   LIKES                  19681 non-null  int64
#  4   COMMENTS               19681 non-null  int64
#  5   TEXT                   19675 non-null  object
#  6   DATE                   19681 non-null  datetime64[ns]
#  7   TYPE(1 PHOTO,2 VIDEO)  19681 non-null  int64
#  8   USERS IN PHOTO         19681 non-null  object
#  9   LINK                   19681 non-null  object
#  10  list_of_tags           13862 non-null  object
#  11  number_of_tags         19681 non-null  int64
#  12  list_of_mentions       6746 non-null   object
#  13  number_of_mentions     19681 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# # **Data Cleaning and Preprocessing**

# %%
# Calculate the total number of records in the dataset
print(f"Total records: {len(data)}")
# Out:
# Total records: 19681

# %%
# Define numeric and categorical features for analysis
numeric_features = [
    'FOLLOWERS', 'FOLLOWING', 'LIKES', 'COMMENTS', 
    'number_of_tags', 'number_of_mentions'
]

# %%
# Calculate descriptive statistics
numeric_stats = data[numeric_features].describe()
numeric_stats
# Out:
#           FOLLOWERS     FOLLOWING          LIKES      COMMENTS  \
# count  1.968100e+04  19681.000000   19681.000000  19681.000000
# mean   6.256413e+04   1489.766831    2497.766983     39.825111
# std    1.042349e+05   2252.675356    5574.988136    447.972795
# min    1.799300e+04      0.000000       0.000000      0.000000
# 25%    2.329900e+04    174.000000     420.000000      1.000000
# 50%    3.669900e+04    506.000000    1073.000000      5.000000
# 75%    6.279100e+04   1367.000000    2683.000000     17.000000
# max    1.134619e+06   7586.000000  158338.000000  26011.000000
#
#        number_of_tags  number_of_mentions
# count    19681.000000        19681.000000
# mean         6.737005            0.723591
# std          8.782144            1.704316
# min          0.000000            0.000000
# 25%          0.000000            0.000000
# 50%          3.000000            0.000000
# 75%         10.000000            1.000000
# max         41.000000           34.000000

# %%
# Define the list of categorical variables
categorical_columns = ['USERNAME', 'TEXT', 'DATE', 'USERS IN PHOTO', 'LINK', 'list_of_tags', 'list_of_mentions']

# Check unique values for categorical features
unique_counts_dict = data[categorical_columns].nunique()
unique_counts_dataframe = unique_counts_dict.reset_index()
unique_counts_dataframe.columns = ['Category', 'Unique_Values']

# Sort the dataframe by the number of unique values
sorted_unique_counts = unique_counts_dataframe.sort_values(by='Unique_Values', ascending=True)
sorted_unique_counts
# Out:
#            Category  Unique_Values
# 3    USERS IN PHOTO             22
# 0          USERNAME           1094
# 6  list_of_mentions           4357
# 5      list_of_tags           9683
# 1              TEXT          17390
# 2              DATE          19538
# 4              LINK          19681

# %%
# Handle missing values by dropping rows or columns
print("Missing values:\n", data.isnull().sum())
# Out:
# Missing values:
#  USERNAME                     0
# FOLLOWERS                    0
# FOLLOWING                    0
# LIKES                        0
# COMMENTS                     0
# TEXT                         6
# DATE                         0
# TYPE(1 PHOTO,2 VIDEO)        0
# USERS IN PHOTO               0
# LINK                         0
# list_of_tags              5819
# number_of_tags               0
# list_of_mentions         12935
# number_of_mentions           0
# dtype: int64

# %%
# Check for duplicate records
duplicates = data.duplicated().sum()
print(f"Number of duplicate records: {duplicates}")
# Out:
# Number of duplicate records: 0

# %%
# Drop missing values and irrelevant columns
data = data.dropna(subset=['TEXT'])

# %%
data = data.dropna(axis=1)

# %%
# Check for missing values
print("Missing values:\n", data.isnull().sum())
# Out:
# Missing values:
#  USERNAME                 0
# FOLLOWERS                0
# FOLLOWING                0
# LIKES                    0
# COMMENTS                 0
# TEXT                     0
# DATE                     0
# TYPE(1 PHOTO,2 VIDEO)    0
# USERS IN PHOTO           0
# LINK                     0
# number_of_tags           0
# number_of_mentions       0
# dtype: int64

# %%
# Add new features: Month, Day of the Week, and Post Timing
data['Month'] = data['DATE'].dt.month
data['Day_of_Week'] = data['DATE'].dt.day_name()

# Categorize post timing into Morning, Afternoon, Evening, and Night
def categorize_post_timing(hour):
    if 8 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 16:
        return 'Afternoon'
    elif 16 <= hour < 20:
        return 'Evening'
    elif 20 <= hour <= 23 or 0 <= hour < 8:
        return 'Night'

data['Post_Timing'] = data['DATE'].dt.hour.apply(categorize_post_timing)

# %%
# Calculate the length of the text in each post
data['Text_Length'] = data['TEXT'].apply(lambda x: len(x.strip()))

# %%
data.head()
# Out:
#      USERNAME  FOLLOWERS  FOLLOWING  LIKES  COMMENTS  \
# 0  georgiou82    1134619        915  18560        95
# 1  georgiou82    1134619        915  17710        86
# 2  georgiou82    1134619        915  11959        79
# 3  georgiou82    1134619        915  13608        37
# 4  georgiou82    1134619        915  15842        62
#
#                                                 TEXT                DATE  \
# 0  Every day is a #newday and every experience is... 2017-02-11 11:05:10
# 1  #goodnight !!! The #weekend is ahead!!! Have a... 2017-02-11 00:33:10
# 2  #tb #2007 #stous31dromous #megatv #greece #new... 2017-02-09 15:51:47
# 3  Cold weather brings people together.... #filmi... 2017-02-08 18:21:57
# 4  The youngest hearts might be the oldest souls.... 2017-02-08 13:03:14
#
#    TYPE(1 PHOTO,2 VIDEO) USERS IN PHOTO  \
# 0                      1              1
# 1                      1              1
# 2                      1              3
# 3                      1              3
# 4                      1              0
#
#                                       LINK  number_of_tags  \
# 0  https://www.instagram.com/p/BQXZpSQjiPj               2
# 1  https://www.instagram.com/p/BQWRUV6j8b-               3
# 2  https://www.instagram.com/p/BQSw2wMj0Bw               7
# 3  https://www.instagram.com/p/BQQdPrLDeRz               2
# 4  https://www.instagram.com/p/BQP4xY7jAXb               4
#
#    number_of_mentions  Month Day_of_Week Post_Timing  Text_Length
# 0                   0      2    Saturday     Morning           56
# 1                   0      2    Saturday       Night           64
# 2                   0      2    Thursday   Afternoon           60
# 3                   2      2   Wednesday     Evening          103
# 4                   0      2   Wednesday   Afternoon           91

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19675 entries, 0 to 19680
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   USERNAME               19675 non-null  object
#  1   FOLLOWERS              19675 non-null  int64
#  2   FOLLOWING              19675 non-null  int64
#  3   LIKES                  19675 non-null  int64
#  4   COMMENTS               19675 non-null  int64
#  5   TEXT                   19675 non-null  object
#  6   DATE                   19675 non-null  datetime64[ns]
#  7   TYPE(1 PHOTO,2 VIDEO)  19675 non-null  int64
#  8   USERS IN PHOTO         19675 non-null  object
#  9   LINK                   19675 non-null  object
#  10  number_of_tags         19675 non-null  int64
#  11  number_of_mentions     19675 non-null  int64
#  12  Month                  19675 non-null  int32
#  13  Day_of_Week            19675 non-null  object
#  14  Post_Timing            19675 non-null  object
#  15  Text_Length            19675 non-null  int64
# dtypes: datetime64[ns](1), int32(1), int64(8), object(6)
# memory usage: 2.5+ MB

# %%
# Rename the 'USERS IN PHOTO' column for better clarity
data.rename(columns={'USERS IN PHOTO': 'Tagged_Users_Count'}, inplace=True)
# Convert Tagged_Users_Count to integer after replacing invalid values
data['Tagged_Users_Count'] = data['Tagged_Users_Count'].replace('-', 0)
data['Tagged_Users_Count'] = data['Tagged_Users_Count'].astype(int)

# %%
# Checking unique values in the Month column
data['Month'].unique()
# Out:
# array([ 2,  1, 12, 11, 10,  9,  8,  7,  4,  5,  3])

# %%
# Checking unique values in the Day of Week column
data['Day_of_Week'].unique()
# Out:
# array(['Saturday', 'Thursday', 'Wednesday', 'Tuesday', 'Monday', 'Friday',
#        'Sunday'], dtype=object)

# %%
# Checking unique values in the Post Timing column
data['Post_Timing'].unique()
# Out:
# array(['Morning', 'Night', 'Afternoon', 'Evening'], dtype=object)

# %%
# Checking unique values in the TYPE (PHOTO, VIDEO) column
data['TYPE(1 PHOTO,2 VIDEO)'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
# Creating the Month Name column from the Month column
data['Month_Name'] = pd.to_datetime(data['Month'], format='%m').dt.month_name()

# Replacing 1 by 'photo' and 2 by 'video' in the TYPE column
data['TYPE(1 PHOTO,2 VIDEO)'] = data['TYPE(1 PHOTO,2 VIDEO)'].map({1: 'photo', 2: 'video'})

# %%
# Create dummy variables for categorical columns
data = pd.get_dummies(data, columns=['Month_Name', 'Day_of_Week', 'Post_Timing', 'TYPE(1 PHOTO,2 VIDEO)'], drop_first=True)

# %%
data.head()
# Out:
#      USERNAME  FOLLOWERS  FOLLOWING  LIKES  COMMENTS  \
# 0  georgiou82    1134619        915  18560        95
# 1  georgiou82    1134619        915  17710        86
# 2  georgiou82    1134619        915  11959        79
# 3  georgiou82    1134619        915  13608        37
# 4  georgiou82    1134619        915  15842        62
#
#                                                 TEXT                DATE  \
# 0  Every day is a #newday and every experience is... 2017-02-11 11:05:10
# 1  #goodnight !!! The #weekend is ahead!!! Have a... 2017-02-11 00:33:10
# 2  #tb #2007 #stous31dromous #megatv #greece #new... 2017-02-09 15:51:47
# 3  Cold weather brings people together.... #filmi... 2017-02-08 18:21:57
# 4  The youngest hearts might be the oldest souls.... 2017-02-08 13:03:14
#
#    Tagged_Users_Count                                     LINK  \
# 0                   1  https://www.instagram.com/p/BQXZpSQjiPj
# 1                   1  https://www.instagram.com/p/BQWRUV6j8b-
# 2                   3  https://www.instagram.com/p/BQSw2wMj0Bw
# 3                   3  https://www.instagram.com/p/BQQdPrLDeRz
# 4                   0  https://www.instagram.com/p/BQP4xY7jAXb
#
#    number_of_tags  ...  Day_of_Week_Monday  Day_of_Week_Saturday  \
# 0               2  ...               False                  True
# 1               3  ...               False                  True
# 2               7  ...               False                 False
# 3               2  ...               False                 False
# 4               4  ...               False                 False
#
#    Day_of_Week_Sunday  Day_of_Week_Thursday  Day_of_Week_Tuesday  \
# 0               False                 False                False
# 1               False                 False                False
# 2               False                  True                False
# 3               False                 False                False
# 4               False                 False                False
#
#    Day_of_Week_Wednesday  Post_Timing_Evening  Post_Timing_Morning  \
# 0                  False                False                 True
# 1                  False                False                False
# 2                  False                False                False
# 3                   True                 True                False
# 4                   True                False                False
#
#    Post_Timing_Night  TYPE(1 PHOTO,2 VIDEO)_video
# 0              False                        False
# 1               True                        False
# 2              False                        False
# 3              False                        False
# 4              False                        False
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19675 entries, 0 to 19680
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   USERNAME                     19675 non-null  object
#  1   FOLLOWERS                    19675 non-null  int64
#  2   FOLLOWING                    19675 non-null  int64
#  3   LIKES                        19675 non-null  int64
#  4   COMMENTS                     19675 non-null  int64
#  5   TEXT                         19675 non-null  object
#  6   DATE                         19675 non-null  datetime64[ns]
#  7   Tagged_Users_Count           19675 non-null  int32
#  8   LINK                         19675 non-null  object
#  9   number_of_tags               19675 non-null  int64
#  10  number_of_mentions           19675 non-null  int64
#  11  Month                        19675 non-null  int32
#  12  Text_Length                  19675 non-null  int64
#  13  Month_Name_August            19675 non-null  bool
#  14  Month_Name_December          19675 non-null  bool
#  15  Month_Name_February          19675 non-null  bool
#  16  Month_Name_January           19675 non-null  bool
#  17  Month_Name_July              19675 non-null  bool
#  18  Month_Name_March             19675 non-null  bool
#  19  Month_Name_May               19675 non-null  bool
#  20  Month_Name_November          19675 non-null  bool
#  21  Month_Name_October           19675 non-null  bool
#  22  Month_Name_September         19675 non-null  bool
#  23  Day_of_Week_Monday           19675 non-null  bool
#  24  Day_of_Week_Saturday         19675 non-null  bool
#  25  Day_of_Week_Sunday           19675 non-null  bool
#  26  Day_of_Week_Thursday         19675 non-null  bool
#  27  Day_of_Week_Tuesday          19675 non-null  bool
#  28  Day_of_Week_Wednesday        19675 non-null  bool
#  29  Post_Timing_Evening          19675 non-null  bool
#  30  Post_Timing_Morning          19675 non-null  bool
#  31  Post_Timing_Night            19675 non-null  bool
#  32  TYPE(1 PHOTO,2 VIDEO)_video  19675 non-null  bool
# dtypes: bool(20), datetime64[ns](1), int32(2), int64(7), object(3)
# memory usage: 2.3+ MB

# %%
columns_to_convert = ['TYPE(1 PHOTO,2 VIDEO)_video','Post_Timing_Evening','Post_Timing_Morning','Post_Timing_Night','Day_of_Week_Monday','Day_of_Week_Saturday','Day_of_Week_Sunday', 'Day_of_Week_Thursday','Day_of_Week_Tuesday','Day_of_Week_Wednesday','Month_Name_August','Month_Name_December','Month_Name_February','Month_Name_January','Month_Name_July','Month_Name_March','Month_Name_May','Month_Name_November','Month_Name_October','Month_Name_September']
data[columns_to_convert] = data[columns_to_convert].astype(int)

# %%
data.head()
# Out:
#      USERNAME  FOLLOWERS  FOLLOWING  LIKES  COMMENTS  \
# 0  georgiou82    1134619        915  18560        95
# 1  georgiou82    1134619        915  17710        86
# 2  georgiou82    1134619        915  11959        79
# 3  georgiou82    1134619        915  13608        37
# 4  georgiou82    1134619        915  15842        62
#
#                                                 TEXT                DATE  \
# 0  Every day is a #newday and every experience is... 2017-02-11 11:05:10
# 1  #goodnight !!! The #weekend is ahead!!! Have a... 2017-02-11 00:33:10
# 2  #tb #2007 #stous31dromous #megatv #greece #new... 2017-02-09 15:51:47
# 3  Cold weather brings people together.... #filmi... 2017-02-08 18:21:57
# 4  The youngest hearts might be the oldest souls.... 2017-02-08 13:03:14
#
#    Tagged_Users_Count                                     LINK  \
# 0                   1  https://www.instagram.com/p/BQXZpSQjiPj
# 1                   1  https://www.instagram.com/p/BQWRUV6j8b-
# 2                   3  https://www.instagram.com/p/BQSw2wMj0Bw
# 3                   3  https://www.instagram.com/p/BQQdPrLDeRz
# 4                   0  https://www.instagram.com/p/BQP4xY7jAXb
#
#    number_of_tags  ...  Day_of_Week_Monday  Day_of_Week_Saturday  \
# 0               2  ...                   0                     1
# 1               3  ...                   0                     1
# 2               7  ...                   0                     0
# 3               2  ...                   0                     0
# 4               4  ...                   0                     0
#
#    Day_of_Week_Sunday  Day_of_Week_Thursday  Day_of_Week_Tuesday  \
# 0                   0                     0                    0
# 1                   0                     0                    0
# 2                   0                     1                    0
# 3                   0                     0                    0
# 4                   0                     0                    0
#
#    Day_of_Week_Wednesday  Post_Timing_Evening  Post_Timing_Morning  \
# 0                      0                    0                    1
# 1                      0                    0                    0
# 2                      0                    0                    0
# 3                      1                    1                    0
# 4                      1                    0                    0
#
#    Post_Timing_Night  TYPE(1 PHOTO,2 VIDEO)_video
# 0                  0                            0
# 1                  1                            0
# 2                  0                            0
# 3                  0                            0
# 4                  0                            0
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19675 entries, 0 to 19680
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   USERNAME                     19675 non-null  object
#  1   FOLLOWERS                    19675 non-null  int64
#  2   FOLLOWING                    19675 non-null  int64
#  3   LIKES                        19675 non-null  int64
#  4   COMMENTS                     19675 non-null  int64
#  5   TEXT                         19675 non-null  object
#  6   DATE                         19675 non-null  datetime64[ns]
#  7   Tagged_Users_Count           19675 non-null  int32
#  8   LINK                         19675 non-null  object
#  9   number_of_tags               19675 non-null  int64
#  10  number_of_mentions           19675 non-null  int64
#  11  Month                        19675 non-null  int32
#  12  Text_Length                  19675 non-null  int64
#  13  Month_Name_August            19675 non-null  int32
#  14  Month_Name_December          19675 non-null  int32
#  15  Month_Name_February          19675 non-null  int32
#  16  Month_Name_January           19675 non-null  int32
#  17  Month_Name_July              19675 non-null  int32
#  18  Month_Name_March             19675 non-null  int32
#  19  Month_Name_May               19675 non-null  int32
#  20  Month_Name_November          19675 non-null  int32
#  21  Month_Name_October           19675 non-null  int32
#  22  Month_Name_September         19675 non-null  int32
#  23  Day_of_Week_Monday           19675 non-null  int32
#  24  Day_of_Week_Saturday         19675 non-null  int32
#  25  Day_of_Week_Sunday           19675 non-null  int32
#  26  Day_of_Week_Thursday         19675 non-null  int32
#  27  Day_of_Week_Tuesday          19675 non-null  int32
#  28  Day_of_Week_Wednesday        19675 non-null  int32
#  29  Post_Timing_Evening          19675 non-null  int32
#  30  Post_Timing_Morning          19675 non-null  int32
#  31  Post_Timing_Night            19675 non-null  int32
#  32  TYPE(1 PHOTO,2 VIDEO)_video  19675 non-null  int32
# dtypes: datetime64[ns](1), int32(22), int64(7), object(3)
# memory usage: 3.5+ MB

# %% [markdown]
# # **Descriptive Statistics and Outlier Detection**

# %%
from scipy.stats import zscore

# Columns to analyze for outliers
columns_of_interest = [
    'FOLLOWERS', 'FOLLOWING', 'LIKES', 'COMMENTS',
    'Tagged_Users_Count', 'number_of_tags',
    'number_of_mentions', 'Text_Length'
]

# %%
# Calculate Z-scores for numeric features to identify outliers
z_scores = data[columns_of_interest].apply(zscore)
# Create a mask for rows where any column's Z-score exceeds 3
outlier_mask = (z_scores.abs() > 3).any(axis=1)
# Filter out the outliers
data_cleaned = data[~outlier_mask]

# Display the number of rows before and after outlier removal
print(f"Original number of rows: {data.shape[0]}")
print(f"Number of rows after outlier removal: {data_cleaned.shape[0]}")
# Out:
# Original number of rows: 19675
# Number of rows after outlier removal: 18276

# %% [markdown]
# # **Correlation Analysis**

# %%
# Select relevant columns from the dataset for calculating the correlation matrix
# These columns include numeric features and dummy variables representing categorical data
columns_for_correlation_matrix = data[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September']]
# Compute the correlation matrix to evaluate the relationships between the selected features
correlation_matrix = columns_for_correlation_matrix.corr()
# Display the correlation matrix
correlation_matrix
# Out:
#                              FOLLOWERS  FOLLOWING  Tagged_Users_Count  \
# FOLLOWERS                     1.000000  -0.093496            0.145211
# FOLLOWING                    -0.093496   1.000000            0.021503
# Tagged_Users_Count            0.145211   0.021503            1.000000
# number_of_tags               -0.043321   0.107250            0.112280
# number_of_mentions           -0.000932   0.102484            0.076426
# Text_Length                  -0.007532   0.056984            0.084958
# TYPE(1 PHOTO,2 VIDEO)_video  -0.007427  -0.054276           -0.099426
# Post_Timing_Evening           0.001737  -0.055901            0.013546
# Post_Timing_Morning          -0.015098   0.010759           -0.012141
# Post_Timing_Night            -0.015618   0.083858           -0.025900
# Day_of_Week_Monday           -0.000598  -0.012990            0.008608
# Day_of_Week_Saturday         -0.009403  -0.007723            0.001507
# Day_of_Week_Sunday           -0.003271  -0.003349           -0.001916
# Day_of_Week_Thursday          0.001990  -0.005995           -0.005710
# Day_of_Week_Wednesday         0.000737   0.019937           -0.000862
# Day_of_Week_Tuesday           0.005066   0.014670            0.005436
# Month_Name_August             0.305785  -0.007506            0.002451
# Month_Name_December           0.039529  -0.005398           -0.001800
# Month_Name_February           0.153487  -0.000046           -0.001107
# Month_Name_January            0.228232  -0.008688            0.010644
# Month_Name_July               0.222446  -0.005460           -0.003118
# Month_Name_March             -0.005591   0.000514           -0.005147
# Month_Name_May               -0.021694   0.014776           -0.003442
# Month_Name_November           0.222446  -0.005460            0.025918
# Month_Name_October            0.287220  -0.007050            0.021403
# Month_Name_September          0.385464  -0.009462            0.051475
#
#                              number_of_tags  number_of_mentions  Text_Length  \
# FOLLOWERS                         -0.043321           -0.000932    -0.007532
# FOLLOWING                          0.107250            0.102484     0.056984
# Tagged_Users_Count                 0.112280            0.076426     0.084958
# number_of_tags                     1.000000            0.107736     0.602237
# number_of_mentions                 0.107736            1.000000     0.279413
# Text_Length                        0.602237            0.279413     1.000000
# TYPE(1 PHOTO,2 VIDEO)_video       -0.005600            0.110804     0.032277
# Post_Timing_Evening                0.007898           -0.002946    -0.003092
# Post_Timing_Morning               -0.019475           -0.002453     0.007051
# Post_Timing_Night                  0.066102            0.039590     0.043394
# Day_of_Week_Monday                 0.010185            0.012395     0.012614
# Day_of_Week_Saturday              -0.006536           -0.009782    -0.010549
# Day_of_Week_Sunday                -0.012881           -0.010824    -0.018372
# Day_of_Week_Thursday              -0.009836           -0.011697     0.004622
# Day_of_Week_Wednesday              0.011722            0.008469     0.001602
# Day_of_Week_Tuesday                0.014011            0.005393     0.006863
# Month_Name_August                  0.033767           -0.010458     0.004088
# Month_Name_December               -0.001508           -0.005244    -0.001325
# Month_Name_February               -0.016149           -0.011531    -0.016318
# Month_Name_January                -0.011340            0.002315    -0.010335
# Month_Name_July                    0.017416           -0.004901     0.005930
# Month_Name_March                  -0.003520           -0.006770    -0.006744
# Month_Name_May                     0.008890            0.000847     0.005063
# Month_Name_November               -0.012626            0.000677    -0.011668
# Month_Name_October                -0.008195           -0.002006    -0.011553
# Month_Name_September              -0.003276            0.005201    -0.011648
#
#                              TYPE(1 PHOTO,2 VIDEO)_video  Post_Timing_Evening  \
# FOLLOWERS                                      -0.007427             0.001737
# FOLLOWING                                      -0.054276            -0.055901
# Tagged_Users_Count                             -0.099426             0.013546
# number_of_tags                                 -0.005600             0.007898
# number_of_mentions                              0.110804            -0.002946
# Text_Length                                     0.032277            -0.003092
# TYPE(1 PHOTO,2 VIDEO)_video                     1.000000             0.024033
# Post_Timing_Evening                             0.024033             1.000000
# Post_Timing_Morning                            -0.013680            -0.214828
# Post_Timing_Night                               0.001728            -0.450582
# Day_of_Week_Monday                             -0.021536             0.019483
# Day_of_Week_Saturday                            0.011181            -0.000154
# Day_of_Week_Sunday                              0.004200             0.003882
# Day_of_Week_Thursday                           -0.000261            -0.005683
# Day_of_Week_Wednesday                          -0.006678            -0.017342
# Day_of_Week_Tuesday                             0.010252            -0.012656
# Month_Name_August                              -0.003712             0.002726
# Month_Name_December                            -0.004025            -0.007202
# Month_Name_February                            -0.005742             0.004952
# Month_Name_January                             -0.002751            -0.003413
# Month_Name_July                                -0.006972            -0.001551
# Month_Name_March                               -0.005196            -0.009298
# Month_Name_May                                  0.003549            -0.019060
# Month_Name_November                            -0.006972             0.003911
# Month_Name_October                             -0.009002             0.005050
# Month_Name_September                           -0.012081             0.000467
#
#                              Post_Timing_Morning  Post_Timing_Night  ...  \
# FOLLOWERS                              -0.015098          -0.015618  ...
# FOLLOWING                               0.010759           0.083858  ...
# Tagged_Users_Count                     -0.012141          -0.025900  ...
# number_of_tags                         -0.019475           0.066102  ...
# number_of_mentions                     -0.002453           0.039590  ...
# Text_Length                             0.007051           0.043394  ...
# TYPE(1 PHOTO,2 VIDEO)_video            -0.013680           0.001728  ...
# Post_Timing_Evening                    -0.214828          -0.450582  ...
# Post_Timing_Morning                     1.000000          -0.284635  ...
# Post_Timing_Night                      -0.284635           1.000000  ...
# Day_of_Week_Monday                      0.002358          -0.018912  ...
# Day_of_Week_Saturday                   -0.002757          -0.010462  ...
# Day_of_Week_Sunday                     -0.024283           0.037219  ...
# Day_of_Week_Thursday                    0.009088          -0.016201  ...
# Day_of_Week_Wednesday                   0.002135           0.014680  ...
# Day_of_Week_Tuesday                     0.012714           0.003529  ...
# Month_Name_August                      -0.005500           0.009457  ...
# Month_Name_December                     0.008141          -0.001034  ...
# Month_Name_February                     0.001740          -0.003848  ...
# Month_Name_January                     -0.010176           0.016719  ...
# Month_Name_July                         0.006775           0.008035  ...
# Month_Name_March                        0.013788          -0.005728  ...
# Month_Name_May                          0.045456          -0.016885  ...
# Month_Name_November                    -0.000553           0.003123  ...
# Month_Name_October                     -0.010176          -0.002312  ...
# Month_Name_September                   -0.000958           0.002573  ...
#
#                              Month_Name_August  Month_Name_December  \
# FOLLOWERS                             0.305785             0.039529
# FOLLOWING                            -0.007506            -0.005398
# Tagged_Users_Count                    0.002451            -0.001800
# number_of_tags                        0.033767            -0.001508
# number_of_mentions                   -0.010458            -0.005244
# Text_Length                           0.004088            -0.001325
# TYPE(1 PHOTO,2 VIDEO)_video          -0.003712            -0.004025
# Post_Timing_Evening                   0.002726            -0.007202
# Post_Timing_Morning                  -0.005500             0.008141
# Post_Timing_Night                     0.009457            -0.001034
# Day_of_Week_Monday                    0.002069             0.017764
# Day_of_Week_Saturday                 -0.007366            -0.005141
# Day_of_Week_Sunday                   -0.008079             0.005868
# Day_of_Week_Thursday                  0.001441            -0.005361
# Day_of_Week_Wednesday                -0.010319            -0.004333
# Day_of_Week_Tuesday                   0.010564            -0.004538
# Month_Name_August                     1.000000            -0.000363
# Month_Name_December                  -0.000363             1.000000
# Month_Name_February                  -0.000984            -0.000413
# Month_Name_January                   -0.000812            -0.000341
# Month_Name_July                      -0.000629            -0.000264
# Month_Name_March                     -0.000469            -0.000197
# Month_Name_May                       -0.007857            -0.003300
# Month_Name_November                  -0.000629            -0.000264
# Month_Name_October                   -0.000812            -0.000341
# Month_Name_September                 -0.001090            -0.000458
#
#                              Month_Name_February  Month_Name_January  \
# FOLLOWERS                               0.153487            0.228232
# FOLLOWING                              -0.000046           -0.008688
# Tagged_Users_Count                     -0.001107            0.010644
# number_of_tags                         -0.016149           -0.011340
# number_of_mentions                     -0.011531            0.002315
# Text_Length                            -0.016318           -0.010335
# TYPE(1 PHOTO,2 VIDEO)_video            -0.005742           -0.002751
# Post_Timing_Evening                     0.004952           -0.003413
# Post_Timing_Morning                     0.001740           -0.010176
# Post_Timing_Night                      -0.003848            0.016719
# Day_of_Week_Monday                     -0.005635            0.014036
# Day_of_Week_Saturday                    0.007504           -0.011499
# Day_of_Week_Sunday                     -0.010414           -0.001966
# Day_of_Week_Thursday                   -0.002035            0.003132
# Day_of_Week_Wednesday                   0.002863           -0.003799
# Day_of_Week_Tuesday                     0.001796            0.001224
# Month_Name_August                      -0.000984           -0.000812
# Month_Name_December                    -0.000413           -0.000341
# Month_Name_February                     1.000000           -0.000924
# Month_Name_January                     -0.000924            1.000000
# Month_Name_July                        -0.000716           -0.000591
# Month_Name_March                       -0.000533           -0.000440
# Month_Name_May                         -0.008940           -0.007380
# Month_Name_November                    -0.000716           -0.000591
# Month_Name_October                     -0.000924           -0.000763
# Month_Name_September                   -0.001240           -0.001024
#
#                              Month_Name_July  Month_Name_March  \
# FOLLOWERS                           0.222446         -0.005591
# FOLLOWING                          -0.005460          0.000514
# Tagged_Users_Count                 -0.003118         -0.005147
# number_of_tags                      0.017416         -0.003520
# number_of_mentions                 -0.004901         -0.006770
# Text_Length                         0.005930         -0.006744
# TYPE(1 PHOTO,2 VIDEO)_video        -0.006972         -0.005196
# Post_Timing_Evening                -0.001551         -0.009298
# Post_Timing_Morning                 0.006775          0.013788
# Post_Timing_Night                   0.008035         -0.005728
# Day_of_Week_Monday                  0.010871          0.002169
# Day_of_Week_Saturday               -0.002206         -0.006637
# Day_of_Week_Sunday                 -0.009315          0.010480
# Day_of_Week_Thursday               -0.009287          0.010537
# Day_of_Week_Wednesday               0.022925         -0.005595
# Day_of_Week_Tuesday                -0.000520         -0.005859
# Month_Name_August                  -0.000629         -0.000469
# Month_Name_December                -0.000264         -0.000197
# Month_Name_February                -0.000716         -0.000533
# Month_Name_January                 -0.000591         -0.000440
# Month_Name_July                     1.000000         -0.000341
# Month_Name_March                   -0.000341          1.000000
# Month_Name_May                     -0.005716         -0.004260
# Month_Name_November                -0.000458         -0.000341
# Month_Name_October                 -0.000591         -0.000440
# Month_Name_September               -0.000793         -0.000591
#
#                              Month_Name_May  Month_Name_November  \
# FOLLOWERS                         -0.021694             0.222446
# FOLLOWING                          0.014776            -0.005460
# Tagged_Users_Count                -0.003442             0.025918
# number_of_tags                     0.008890            -0.012626
# number_of_mentions                 0.000847             0.000677
# Text_Length                        0.005063            -0.011668
# TYPE(1 PHOTO,2 VIDEO)_video        0.003549            -0.006972
# Post_Timing_Evening               -0.019060             0.003911
# Post_Timing_Morning                0.045456            -0.000553
# Post_Timing_Night                 -0.016885             0.003123
# Day_of_Week_Monday                 0.483319             0.010871
# Day_of_Week_Saturday              -0.111227            -0.008905
# Day_of_Week_Sunday                -0.116346            -0.002822
# Day_of_Week_Thursday              -0.115435            -0.002780
# Day_of_Week_Wednesday             -0.093756            -0.007507
# Day_of_Week_Tuesday                0.065474             0.006821
# Month_Name_August                 -0.007857            -0.000629
# Month_Name_December               -0.003300            -0.000264
# Month_Name_February               -0.008940            -0.000716
# Month_Name_January                -0.007380            -0.000591
# Month_Name_July                   -0.005716            -0.000458
# Month_Name_March                  -0.004260            -0.000341
# Month_Name_May                     1.000000            -0.005716
# Month_Name_November               -0.005716             1.000000
# Month_Name_October                -0.007380            -0.000591
# Month_Name_September              -0.009905            -0.000793
#
#                              Month_Name_October  Month_Name_September
# FOLLOWERS                              0.287220              0.385464
# FOLLOWING                             -0.007050             -0.009462
# Tagged_Users_Count                     0.021403              0.051475
# number_of_tags                        -0.008195             -0.003276
# number_of_mentions                    -0.002006              0.005201
# Text_Length                           -0.011553             -0.011648
# TYPE(1 PHOTO,2 VIDEO)_video           -0.009002             -0.012081
# Post_Timing_Evening                    0.005050              0.000467
# Post_Timing_Morning                   -0.010176             -0.000958
# Post_Timing_Night                     -0.002312              0.002573
# Day_of_Week_Monday                    -0.006521             -0.004154
# Day_of_Week_Saturday                  -0.001118             -0.007693
# Day_of_Week_Sunday                     0.008095              0.010114
# Day_of_Week_Thursday                  -0.006950             -0.001058
# Day_of_Week_Wednesday                  0.002095             -0.004219
# Day_of_Week_Tuesday                    0.001224              0.003339
# Month_Name_August                     -0.000812             -0.001090
# Month_Name_December                   -0.000341             -0.000458
# Month_Name_February                   -0.000924             -0.001240
# Month_Name_January                    -0.000763             -0.001024
# Month_Name_July                       -0.000591             -0.000793
# Month_Name_March                      -0.000440             -0.000591
# Month_Name_May                        -0.007380             -0.009905
# Month_Name_November                   -0.000591             -0.000793
# Month_Name_October                     1.000000             -0.001024
# Month_Name_September                  -0.001024              1.000000
#
# [26 rows x 26 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant


# Calculate Variance Inflation Factor (VIF) for independent variables
X = data[[
    'FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length']]

# Add a constant term to the model for the intercept
X = add_constant(X)

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#               Feature       VIF
# 0               const  2.685209
# 1           FOLLOWERS  1.034455
# 2           FOLLOWING  1.030143
# 3  Tagged_Users_Count  1.041214
# 4      number_of_tags  1.609585
# 5  number_of_mentions  1.106235
# 6         Text_Length  1.695642

# %% [markdown]
# # **Linear Regression for Likes and Comments**

# %% [markdown]
# ## Regression Analysis for Predicting Likes

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count','number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September']]
DV = data[['LIKES']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     590.0
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:36:17   Log-Likelihood:            -1.9194e+05
# No. Observations:               19675   AIC:                         3.839e+05
# Df Residuals:                   19648   BIC:                         3.841e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         411.7460    100.650      4.091      0.000     214.463     609.029
# FOLLOWERS                       0.0482      0.000    114.818      0.000       0.047       0.049
# FOLLOWING                      -0.1530      0.014    -11.317      0.000      -0.180      -0.127
# Tagged_Users_Count            -20.1703     16.320     -1.236      0.217     -52.159      11.818
# number_of_tags                 -5.4321      4.327     -1.255      0.209     -13.913       3.049
# number_of_mentions            -46.6480     18.516     -2.519      0.012     -82.941     -10.355
# Text_Length                    -0.4546      0.211     -2.157      0.031      -0.868      -0.041
# TYPE(1 PHOTO,2 VIDEO)_video  -876.8623    102.639     -8.543      0.000   -1078.044    -675.680
# Post_Timing_Evening          -130.7906     83.890     -1.559      0.119    -295.222      33.641
# Post_Timing_Morning          -427.7979    104.779     -4.083      0.000    -633.174    -222.422
# Post_Timing_Night            -135.7340     77.302     -1.756      0.079    -287.252      15.784
# Day_of_Week_Monday             69.8207    118.313      0.590      0.555    -162.082     301.724
# Day_of_Week_Saturday         -240.3670    108.395     -2.218      0.027    -452.830     -27.904
# Day_of_Week_Sunday           -216.3180    106.405     -2.033      0.042    -424.881      -7.755
# Day_of_Week_Thursday          -50.8429    106.474     -0.478      0.633    -259.541     157.855
# Day_of_Week_Wednesday         -21.4248    117.668     -0.182      0.856    -252.065     209.215
# Day_of_Week_Tuesday          -106.6255    115.880     -0.920      0.358    -333.761     120.510
# Month_Name_August           -4.245e+04   1112.002    -38.173      0.000   -4.46e+04   -4.03e+04
# Month_Name_December         -1.599e+04   2416.309     -6.616      0.000   -2.07e+04   -1.12e+04
# Month_Name_February         -1.757e+04    913.463    -19.239      0.000   -1.94e+04   -1.58e+04
# Month_Name_January          -3.192e+04   1136.887    -28.073      0.000   -3.41e+04   -2.97e+04
# Month_Name_July             -4.038e+04   1466.051    -27.542      0.000   -4.33e+04   -3.75e+04
# Month_Name_March              237.6505   1868.607      0.127      0.899   -3424.977    3900.278
# Month_Name_May               -593.6209    138.554     -4.284      0.000    -865.198    -322.044
# Month_Name_November         -3.886e+04   1462.888    -26.567      0.000   -4.17e+04    -3.6e+04
# Month_Name_October          -3.708e+04   1168.340    -31.737      0.000   -3.94e+04   -3.48e+04
# Month_Name_September        -3.827e+04    920.476    -41.574      0.000   -4.01e+04   -3.65e+04
# ==============================================================================
# Omnibus:                    31777.742   Durbin-Watson:                   0.562
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         42646990.651
# Skew:                          10.363   Prob(JB):                         0.00
# Kurtosis:                     230.139   Cond. No.                     9.79e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.79e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Standardized Regression Analysis for Predicting Likes

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count','number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September']]
DV = data[['LIKES']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)

# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     590.0
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:36:29   Log-Likelihood:                -22241.
# No. Observations:               19675   AIC:                         4.454e+04
# Df Residuals:                   19648   BIC:                         4.475e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        2.093e-16      0.005   3.91e-14      1.000      -0.010       0.010
# FOLLOWERS                       0.8929      0.008    114.818      0.000       0.878       0.908
# FOLLOWING                      -0.0619      0.005    -11.317      0.000      -0.073      -0.051
# Tagged_Users_Count             -0.0068      0.006     -1.236      0.217      -0.018       0.004
# number_of_tags                 -0.0086      0.007     -1.255      0.209      -0.022       0.005
# number_of_mentions             -0.0143      0.006     -2.519      0.012      -0.025      -0.003
# Text_Length                    -0.0151      0.007     -2.157      0.031      -0.029      -0.001
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0464      0.005     -8.543      0.000      -0.057      -0.036
# Post_Timing_Evening            -0.0102      0.007     -1.559      0.119      -0.023       0.003
# Post_Timing_Morning            -0.0249      0.006     -4.083      0.000      -0.037      -0.013
# Post_Timing_Night              -0.0118      0.007     -1.756      0.079      -0.025       0.001
# Day_of_Week_Monday              0.0045      0.008      0.590      0.555      -0.010       0.019
# Day_of_Week_Saturday           -0.0153      0.007     -2.218      0.027      -0.029      -0.002
# Day_of_Week_Sunday             -0.0142      0.007     -2.033      0.042      -0.028      -0.001
# Day_of_Week_Thursday           -0.0033      0.007     -0.478      0.633      -0.017       0.010
# Day_of_Week_Wednesday          -0.0012      0.007     -0.182      0.856      -0.014       0.012
# Day_of_Week_Tuesday            -0.0062      0.007     -0.920      0.358      -0.019       0.007
# Month_Name_August              -0.2240      0.006    -38.173      0.000      -0.235      -0.212
# Month_Name_December            -0.0354      0.005     -6.616      0.000      -0.046      -0.025
# Month_Name_February            -0.1055      0.005    -19.239      0.000      -0.116      -0.095
# Month_Name_January             -0.1582      0.006    -28.073      0.000      -0.169      -0.147
# Month_Name_July                -0.1550      0.006    -27.542      0.000      -0.166      -0.144
# Month_Name_March                0.0007      0.005      0.127      0.899      -0.010       0.011
# Month_Name_May                 -0.0266      0.006     -4.284      0.000      -0.039      -0.014
# Month_Name_November            -0.1492      0.006    -26.567      0.000      -0.160      -0.138
# Month_Name_October             -0.1838      0.006    -31.737      0.000      -0.195      -0.172
# Month_Name_September           -0.2544      0.006    -41.574      0.000      -0.266      -0.242
# ==============================================================================
# Omnibus:                    31777.742   Durbin-Watson:                   0.562
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         42646990.651
# Skew:                          10.363   Prob(JB):                         0.00
# Kurtosis:                     230.139   Cond. No.                         3.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Regression Analysis for Predicting Comments

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count','number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September']]
DV = data[['COMMENTS']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     57.08
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):          5.40e-286
# Time:                        20:36:39   Log-Likelihood:            -1.4731e+05
# No. Observations:               19675   AIC:                         2.947e+05
# Df Residuals:                   19648   BIC:                         2.949e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -5.6174     10.419     -0.539      0.590     -26.040      14.805
# FOLLOWERS                       0.0016   4.35e-05     37.053      0.000       0.002       0.002
# FOLLOWING                      -0.0004      0.001     -0.299      0.765      -0.003       0.002
# Tagged_Users_Count             -9.5987      1.689     -5.682      0.000     -12.910      -6.287
# number_of_tags                 -0.6104      0.448     -1.363      0.173      -1.488       0.268
# number_of_mentions              0.3331      1.917      0.174      0.862      -3.424       4.090
# Text_Length                     0.0404      0.022      1.852      0.064      -0.002       0.083
# TYPE(1 PHOTO,2 VIDEO)_video   -24.0824     10.625     -2.267      0.023     -44.908      -3.256
# Post_Timing_Evening           -30.8510      8.684     -3.553      0.000     -47.873     -13.829
# Post_Timing_Morning           -21.8486     10.847     -2.014      0.044     -43.109      -0.588
# Post_Timing_Night             -35.7369      8.002     -4.466      0.000     -51.422     -20.052
# Day_of_Week_Monday              9.6636     12.248      0.789      0.430     -14.343      33.670
# Day_of_Week_Saturday          -31.8558     11.221     -2.839      0.005     -53.850      -9.862
# Day_of_Week_Sunday            -24.9646     11.015     -2.266      0.023     -46.555      -3.375
# Day_of_Week_Thursday          -18.2756     11.022     -1.658      0.097     -39.880       3.328
# Day_of_Week_Wednesday         -18.0933     12.181     -1.485      0.137     -41.969       5.782
# Day_of_Week_Tuesday           -15.0042     11.996     -1.251      0.211     -38.517       8.508
# Month_Name_August           -1712.3496    115.112    -14.875      0.000   -1937.980   -1486.719
# Month_Name_December          -568.8505    250.132     -2.274      0.023   -1059.130     -78.571
# Month_Name_February          -770.8800     94.560     -8.152      0.000    -956.226    -585.534
# Month_Name_January          -1337.1623    117.688    -11.362      0.000   -1567.842   -1106.483
# Month_Name_July             -1719.8850    151.763    -11.333      0.000   -2017.353   -1422.417
# Month_Name_March               -1.5941    193.435     -0.008      0.993    -380.743     377.555
# Month_Name_May                -36.9816     14.343     -2.578      0.010     -65.095      -8.868
# Month_Name_November         -1682.7615    151.436    -11.112      0.000   -1979.588   -1385.935
# Month_Name_October          -1679.7924    120.944    -13.889      0.000   -1916.854   -1442.731
# Month_Name_September        -1693.4865     95.286    -17.773      0.000   -1880.255   -1506.718
# ==============================================================================
# Omnibus:                    52815.136   Durbin-Watson:                   0.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1672870105.728
# Skew:                          32.735   Prob(JB):                         0.00
# Kurtosis:                    1429.996   Cond. No.                     9.79e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.79e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Standardized Regression Analysis for Predicting Comments

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count','number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September']]
DV = data[['COMMENTS']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)

# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     57.08
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):          5.40e-286
# Time:                        20:36:54   Log-Likelihood:                -27201.
# No. Observations:               19675   AIC:                         5.446e+04
# Df Residuals:                   19648   BIC:                         5.467e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -4.534e-16      0.007  -6.59e-14      1.000      -0.013       0.013
# FOLLOWERS                       0.3708      0.010     37.053      0.000       0.351       0.390
# FOLLOWING                      -0.0021      0.007     -0.299      0.765      -0.016       0.012
# Tagged_Users_Count             -0.0403      0.007     -5.682      0.000      -0.054      -0.026
# number_of_tags                 -0.0120      0.009     -1.363      0.173      -0.029       0.005
# number_of_mentions              0.0013      0.007      0.174      0.862      -0.013       0.016
# Text_Length                     0.0166      0.009      1.852      0.064      -0.001       0.034
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0158      0.007     -2.267      0.023      -0.030      -0.002
# Post_Timing_Evening            -0.0300      0.008     -3.553      0.000      -0.046      -0.013
# Post_Timing_Morning            -0.0158      0.008     -2.014      0.044      -0.031      -0.000
# Post_Timing_Night              -0.0386      0.009     -4.466      0.000      -0.056      -0.022
# Day_of_Week_Monday              0.0077      0.010      0.789      0.430      -0.011       0.027
# Day_of_Week_Saturday           -0.0252      0.009     -2.839      0.005      -0.043      -0.008
# Day_of_Week_Sunday             -0.0204      0.009     -2.266      0.023      -0.038      -0.003
# Day_of_Week_Thursday           -0.0149      0.009     -1.658      0.097      -0.033       0.003
# Day_of_Week_Wednesday          -0.0126      0.008     -1.485      0.137      -0.029       0.004
# Day_of_Week_Tuesday            -0.0108      0.009     -1.251      0.211      -0.028       0.006
# Month_Name_August              -0.1123      0.008    -14.875      0.000      -0.127      -0.097
# Month_Name_December            -0.0157      0.007     -2.274      0.023      -0.029      -0.002
# Month_Name_February            -0.0575      0.007     -8.152      0.000      -0.071      -0.044
# Month_Name_January             -0.0824      0.007    -11.362      0.000      -0.097      -0.068
# Month_Name_July                -0.0821      0.007    -11.333      0.000      -0.096      -0.068
# Month_Name_March            -5.671e-05      0.007     -0.008      0.993      -0.014       0.013
# Month_Name_May                 -0.0206      0.008     -2.578      0.010      -0.036      -0.005
# Month_Name_November            -0.0803      0.007    -11.112      0.000      -0.094      -0.066
# Month_Name_October             -0.1035      0.007    -13.889      0.000      -0.118      -0.089
# Month_Name_September           -0.1399      0.008    -17.773      0.000      -0.155      -0.124
# ==============================================================================
# Omnibus:                    52815.136   Durbin-Watson:                   0.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1672870105.728
# Skew:                          32.735   Prob(JB):                         0.00
# Kurtosis:                    1429.996   Cond. No.                         3.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # **Creating and Analyzing New Variables**

# %%
data_new = data

# %%
# Create new features: Count of question marks and count of exclamation marks
data_new['Count_of_question_mark'] = data_new['TEXT'].str.count(r'\?')
data_new['Count_of_exclamation_markt'] = data_new['TEXT'].str.count(r'\!')

# %%
# Create new features: Count of keywords for engagement
import re

# List of keywords related to engagement
keywords_for_engagement = [
    'love', 'amazing', 'incredible', 'awesome', 'fantastic', 'beautiful', 'wonderful', 'perfect', 
    'stunning', 'jaw-dropping', 'heartwarming', 'inspiring', 'exciting', 'powerful', 'fun', 
    'comment', 'share', 'like', 'follow', 'tag', 'subscribe', 'join', 'click', 'swipe', 'check', 
    'explore', 'recommend', 'vote', 'participate', 'donate', 'challenge', 'contest', 'win',
    'reply', 'respond', 'engage', 'message', 'interact', 'shoutout', 'mention', 'post', 'update', 
    'buzz', 'reaction', 'spotlight', 'feature', 'giveaway', 'free', 'discount', 'exclusive', 
    'special', 'deal', 'offer', 'price', 'sale', 'coupon', 'access', 'invitation', 'limited',
    'please', 'help', 'support', 'favor', 'contribute', 'spread', 'share', 'like', 'comment', 
    '#love', '#instagood', '#follow', '#likeforlike', '#commentforcomment', '#explorepage', 
    '#foryou', '#igers', '#viral', '#fashion', '#style', '#cute', '#funny', '#fitness', '#motivation'
]

data_new['keywords_for_engagement'] = data_new['TEXT'].apply(lambda x: sum([1 for word in keywords_for_engagement if re.search(r'\b' + re.escape(word) + r'\b', x, re.IGNORECASE)]))
data_new['keywords_for_engagement'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 8, 7, 9], dtype=int64)

# %%
# Create new features: Count of emojis for engagement
import re

# List of emojis related to engagement
emojis_for_engagement = [
    '❤️', '🧡', '💛', '💚', '💙', '💜', '🖤', '🤍', '💖', '💘', '💝', '💗', '💓', '💞', '💕', 
    '😊', '😁', '😍', '😋', '😃', '🤩', '😎', '🙌', '✨', '🌟', '🌈', '🤗', '💪', '🥳', '🎉', 
    '🥰', '🌸', '👏', '🏆', '🎯', '🥇', '💥', '🔥', '💯', '💬', '🎉', '🎈', '🏅', '🎁', '🏆', 
    '🎶', '🌟', '🥂', '🍾', '😘', '😽', '💋', '🥰', '💖', '💕', '💑', '👩‍❤️‍👩', '👨‍❤️‍👨', 
    '🚀', '🌍', '🌎', '🌏', '🔥', '✨', '📸', '🎥', '🏖️', '📝', '📲', '📢', '🔔', '🛎️', '🔑', 
    '🚨', '🏁', '🆗', '⬇️'
]

# Create a new column that counts the occurrence of any engagement-related emojis in the TEXT column, case-insensitive
data_new['emojis_for_engagement'] = data_new['TEXT'].apply(lambda x: sum([1 for emoji in emojis_for_engagement if emoji in x]))

# Display the updated dataframe with the new column
data_new['emojis_for_engagement'].unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19675 entries, 0 to 19680
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   USERNAME                     19675 non-null  object
#  1   FOLLOWERS                    19675 non-null  int64
#  2   FOLLOWING                    19675 non-null  int64
#  3   LIKES                        19675 non-null  int64
#  4   COMMENTS                     19675 non-null  int64
#  5   TEXT                         19675 non-null  object
#  6   DATE                         19675 non-null  datetime64[ns]
#  7   Tagged_Users_Count           19675 non-null  int32
#  8   LINK                         19675 non-null  object
#  9   number_of_tags               19675 non-null  int64
#  10  number_of_mentions           19675 non-null  int64
#  11  Month                        19675 non-null  int32
#  12  Text_Length                  19675 non-null  int64
#  13  Month_Name_August            19675 non-null  int32
#  14  Month_Name_December          19675 non-null  int32
#  15  Month_Name_February          19675 non-null  int32
#  16  Month_Name_January           19675 non-null  int32
#  17  Month_Name_July              19675 non-null  int32
#  18  Month_Name_March             19675 non-null  int32
#  19  Month_Name_May               19675 non-null  int32
#  20  Month_Name_November          19675 non-null  int32
#  21  Month_Name_October           19675 non-null  int32
#  22  Month_Name_September         19675 non-null  int32
#  23  Day_of_Week_Monday           19675 non-null  int32
#  24  Day_of_Week_Saturday         19675 non-null  int32
#  25  Day_of_Week_Sunday           19675 non-null  int32
#  26  Day_of_Week_Thursday         19675 non-null  int32
#  27  Day_of_Week_Tuesday          19675 non-null  int32
#  28  Day_of_Week_Wednesday        19675 non-null  int32
#  29  Post_Timing_Evening          19675 non-null  int32
#  30  Post_Timing_Morning          19675 non-null  int32
#  31  Post_Timing_Night            19675 non-null  int32
#  32  TYPE(1 PHOTO,2 VIDEO)_video  19675 non-null  int32
#  33  Count_of_question_mark       19675 non-null  int64
#  34  Count_of_exclamation_markt   19675 non-null  int64
#  35  keywords_for_engagement      19675 non-null  int64
#  36  emojis_for_engagement        19675 non-null  int64
# dtypes: datetime64[ns](1), int32(22), int64(11), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# ## Correlation Matrix Analysis for New Variables

# %%
correlation_matrix_columns = data_new[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
correlation_matrix = correlation_matrix_columns.corr()
correlation_matrix
# Out:
#                              FOLLOWERS  FOLLOWING  Tagged_Users_Count  \
# FOLLOWERS                     1.000000  -0.093496            0.145211
# FOLLOWING                    -0.093496   1.000000            0.021503
# Tagged_Users_Count            0.145211   0.021503            1.000000
# number_of_tags               -0.043321   0.107250            0.112280
# number_of_mentions           -0.000932   0.102484            0.076426
# Text_Length                  -0.007532   0.056984            0.084958
# TYPE(1 PHOTO,2 VIDEO)_video  -0.007427  -0.054276           -0.099426
# Post_Timing_Evening           0.001737  -0.055901            0.013546
# Post_Timing_Morning          -0.015098   0.010759           -0.012141
# Post_Timing_Night            -0.015618   0.083858           -0.025900
# Day_of_Week_Monday           -0.000598  -0.012990            0.008608
# Day_of_Week_Saturday         -0.009403  -0.007723            0.001507
# Day_of_Week_Sunday           -0.003271  -0.003349           -0.001916
# Day_of_Week_Thursday          0.001990  -0.005995           -0.005710
# Day_of_Week_Wednesday         0.000737   0.019937           -0.000862
# Day_of_Week_Tuesday           0.005066   0.014670            0.005436
# Month_Name_August             0.305785  -0.007506            0.002451
# Month_Name_December           0.039529  -0.005398           -0.001800
# Month_Name_February           0.153487  -0.000046           -0.001107
# Month_Name_January            0.228232  -0.008688            0.010644
# Month_Name_July               0.222446  -0.005460           -0.003118
# Month_Name_March             -0.005591   0.000514           -0.005147
# Month_Name_May               -0.021694   0.014776           -0.003442
# Month_Name_November           0.222446  -0.005460            0.025918
# Month_Name_October            0.287220  -0.007050            0.021403
# Month_Name_September          0.385464  -0.009462            0.051475
# Count_of_question_mark       -0.044039   0.030003            0.024505
# keywords_for_engagement       0.002734   0.052091            0.067118
# emojis_for_engagement        -0.009812  -0.024599            0.041293
#
#                              number_of_tags  number_of_mentions  Text_Length  \
# FOLLOWERS                         -0.043321           -0.000932    -0.007532
# FOLLOWING                          0.107250            0.102484     0.056984
# Tagged_Users_Count                 0.112280            0.076426     0.084958
# number_of_tags                     1.000000            0.107736     0.602237
# number_of_mentions                 0.107736            1.000000     0.279413
# Text_Length                        0.602237            0.279413     1.000000
# TYPE(1 PHOTO,2 VIDEO)_video       -0.005600            0.110804     0.032277
# Post_Timing_Evening                0.007898           -0.002946    -0.003092
# Post_Timing_Morning               -0.019475           -0.002453     0.007051
# Post_Timing_Night                  0.066102            0.039590     0.043394
# Day_of_Week_Monday                 0.010185            0.012395     0.012614
# Day_of_Week_Saturday              -0.006536           -0.009782    -0.010549
# Day_of_Week_Sunday                -0.012881           -0.010824    -0.018372
# Day_of_Week_Thursday              -0.009836           -0.011697     0.004622
# Day_of_Week_Wednesday              0.011722            0.008469     0.001602
# Day_of_Week_Tuesday                0.014011            0.005393     0.006863
# Month_Name_August                  0.033767           -0.010458     0.004088
# Month_Name_December               -0.001508           -0.005244    -0.001325
# Month_Name_February               -0.016149           -0.011531    -0.016318
# Month_Name_January                -0.011340            0.002315    -0.010335
# Month_Name_July                    0.017416           -0.004901     0.005930
# Month_Name_March                  -0.003520           -0.006770    -0.006744
# Month_Name_May                     0.008890            0.000847     0.005063
# Month_Name_November               -0.012626            0.000677    -0.011668
# Month_Name_October                -0.008195           -0.002006    -0.011553
# Month_Name_September              -0.003276            0.005201    -0.011648
# Count_of_question_mark             0.133918            0.155970     0.194904
# keywords_for_engagement            0.396670            0.094327     0.326648
# emojis_for_engagement              0.075297            0.015842     0.079328
#
#                              TYPE(1 PHOTO,2 VIDEO)_video  Post_Timing_Evening  \
# FOLLOWERS                                      -0.007427             0.001737
# FOLLOWING                                      -0.054276            -0.055901
# Tagged_Users_Count                             -0.099426             0.013546
# number_of_tags                                 -0.005600             0.007898
# number_of_mentions                              0.110804            -0.002946
# Text_Length                                     0.032277            -0.003092
# TYPE(1 PHOTO,2 VIDEO)_video                     1.000000             0.024033
# Post_Timing_Evening                             0.024033             1.000000
# Post_Timing_Morning                            -0.013680            -0.214828
# Post_Timing_Night                               0.001728            -0.450582
# Day_of_Week_Monday                             -0.021536             0.019483
# Day_of_Week_Saturday                            0.011181            -0.000154
# Day_of_Week_Sunday                              0.004200             0.003882
# Day_of_Week_Thursday                           -0.000261            -0.005683
# Day_of_Week_Wednesday                          -0.006678            -0.017342
# Day_of_Week_Tuesday                             0.010252            -0.012656
# Month_Name_August                              -0.003712             0.002726
# Month_Name_December                            -0.004025            -0.007202
# Month_Name_February                            -0.005742             0.004952
# Month_Name_January                             -0.002751            -0.003413
# Month_Name_July                                -0.006972            -0.001551
# Month_Name_March                               -0.005196            -0.009298
# Month_Name_May                                  0.003549            -0.019060
# Month_Name_November                            -0.006972             0.003911
# Month_Name_October                             -0.009002             0.005050
# Month_Name_September                           -0.012081             0.000467
# Count_of_question_mark                         -0.001586            -0.004083
# keywords_for_engagement                        -0.047633             0.021948
# emojis_for_engagement                          -0.031936            -0.002971
#
#                              Post_Timing_Morning  Post_Timing_Night  ...  \
# FOLLOWERS                              -0.015098          -0.015618  ...
# FOLLOWING                               0.010759           0.083858  ...
# Tagged_Users_Count                     -0.012141          -0.025900  ...
# number_of_tags                         -0.019475           0.066102  ...
# number_of_mentions                     -0.002453           0.039590  ...
# Text_Length                             0.007051           0.043394  ...
# TYPE(1 PHOTO,2 VIDEO)_video            -0.013680           0.001728  ...
# Post_Timing_Evening                    -0.214828          -0.450582  ...
# Post_Timing_Morning                     1.000000          -0.284635  ...
# Post_Timing_Night                      -0.284635           1.000000  ...
# Day_of_Week_Monday                      0.002358          -0.018912  ...
# Day_of_Week_Saturday                   -0.002757          -0.010462  ...
# Day_of_Week_Sunday                     -0.024283           0.037219  ...
# Day_of_Week_Thursday                    0.009088          -0.016201  ...
# Day_of_Week_Wednesday                   0.002135           0.014680  ...
# Day_of_Week_Tuesday                     0.012714           0.003529  ...
# Month_Name_August                      -0.005500           0.009457  ...
# Month_Name_December                     0.008141          -0.001034  ...
# Month_Name_February                     0.001740          -0.003848  ...
# Month_Name_January                     -0.010176           0.016719  ...
# Month_Name_July                         0.006775           0.008035  ...
# Month_Name_March                        0.013788          -0.005728  ...
# Month_Name_May                          0.045456          -0.016885  ...
# Month_Name_November                    -0.000553           0.003123  ...
# Month_Name_October                     -0.010176          -0.002312  ...
# Month_Name_September                   -0.000958           0.002573  ...
# Count_of_question_mark                 -0.018319           0.036754  ...
# keywords_for_engagement                 0.017968          -0.022956  ...
# emojis_for_engagement                   0.001938           0.006212  ...
#
#                              Month_Name_January  Month_Name_July  \
# FOLLOWERS                              0.228232         0.222446
# FOLLOWING                             -0.008688        -0.005460
# Tagged_Users_Count                     0.010644        -0.003118
# number_of_tags                        -0.011340         0.017416
# number_of_mentions                     0.002315        -0.004901
# Text_Length                           -0.010335         0.005930
# TYPE(1 PHOTO,2 VIDEO)_video           -0.002751        -0.006972
# Post_Timing_Evening                   -0.003413        -0.001551
# Post_Timing_Morning                   -0.010176         0.006775
# Post_Timing_Night                      0.016719         0.008035
# Day_of_Week_Monday                     0.014036         0.010871
# Day_of_Week_Saturday                  -0.011499        -0.002206
# Day_of_Week_Sunday                    -0.001966        -0.009315
# Day_of_Week_Thursday                   0.003132        -0.009287
# Day_of_Week_Wednesday                 -0.003799         0.022925
# Day_of_Week_Tuesday                    0.001224        -0.000520
# Month_Name_August                     -0.000812        -0.000629
# Month_Name_December                   -0.000341        -0.000264
# Month_Name_February                   -0.000924        -0.000716
# Month_Name_January                     1.000000        -0.000591
# Month_Name_July                       -0.000591         1.000000
# Month_Name_March                      -0.000440        -0.000341
# Month_Name_May                        -0.007380        -0.005716
# Month_Name_November                   -0.000591        -0.000458
# Month_Name_October                    -0.000763        -0.000591
# Month_Name_September                  -0.001024        -0.000793
# Count_of_question_mark                -0.009331        -0.011062
# keywords_for_engagement               -0.009306         0.021421
# emojis_for_engagement                 -0.007137        -0.005527
#
#                              Month_Name_March  Month_Name_May  \
# FOLLOWERS                           -0.005591       -0.021694
# FOLLOWING                            0.000514        0.014776
# Tagged_Users_Count                  -0.005147       -0.003442
# number_of_tags                      -0.003520        0.008890
# number_of_mentions                  -0.006770        0.000847
# Text_Length                         -0.006744        0.005063
# TYPE(1 PHOTO,2 VIDEO)_video         -0.005196        0.003549
# Post_Timing_Evening                 -0.009298       -0.019060
# Post_Timing_Morning                  0.013788        0.045456
# Post_Timing_Night                   -0.005728       -0.016885
# Day_of_Week_Monday                   0.002169        0.483319
# Day_of_Week_Saturday                -0.006637       -0.111227
# Day_of_Week_Sunday                   0.010480       -0.116346
# Day_of_Week_Thursday                 0.010537       -0.115435
# Day_of_Week_Wednesday               -0.005595       -0.093756
# Day_of_Week_Tuesday                 -0.005859        0.065474
# Month_Name_August                   -0.000469       -0.007857
# Month_Name_December                 -0.000197       -0.003300
# Month_Name_February                 -0.000533       -0.008940
# Month_Name_January                  -0.000440       -0.007380
# Month_Name_July                     -0.000341       -0.005716
# Month_Name_March                     1.000000       -0.004260
# Month_Name_May                      -0.004260        1.000000
# Month_Name_November                 -0.000341       -0.005716
# Month_Name_October                  -0.000440       -0.007380
# Month_Name_September                -0.000591       -0.009905
# Count_of_question_mark               0.001284        0.038091
# keywords_for_engagement              0.010350        0.008510
# emojis_for_engagement               -0.004119        0.013101
#
#                              Month_Name_November  Month_Name_October  \
# FOLLOWERS                               0.222446            0.287220
# FOLLOWING                              -0.005460           -0.007050
# Tagged_Users_Count                      0.025918            0.021403
# number_of_tags                         -0.012626           -0.008195
# number_of_mentions                      0.000677           -0.002006
# Text_Length                            -0.011668           -0.011553
# TYPE(1 PHOTO,2 VIDEO)_video            -0.006972           -0.009002
# Post_Timing_Evening                     0.003911            0.005050
# Post_Timing_Morning                    -0.000553           -0.010176
# Post_Timing_Night                       0.003123           -0.002312
# Day_of_Week_Monday                      0.010871           -0.006521
# Day_of_Week_Saturday                   -0.008905           -0.001118
# Day_of_Week_Sunday                     -0.002822            0.008095
# Day_of_Week_Thursday                   -0.002780           -0.006950
# Day_of_Week_Wednesday                  -0.007507            0.002095
# Day_of_Week_Tuesday                     0.006821            0.001224
# Month_Name_August                      -0.000629           -0.000812
# Month_Name_December                    -0.000264           -0.000341
# Month_Name_February                    -0.000716           -0.000924
# Month_Name_January                     -0.000591           -0.000763
# Month_Name_July                        -0.000458           -0.000591
# Month_Name_March                       -0.000341           -0.000440
# Month_Name_May                         -0.005716           -0.007380
# Month_Name_November                     1.000000           -0.000591
# Month_Name_October                     -0.000591            1.000000
# Month_Name_September                   -0.000793           -0.001024
# Count_of_question_mark                 -0.011062           -0.014284
# keywords_for_engagement                -0.003692           -0.005415
# emojis_for_engagement                  -0.005527           -0.007137
#
#                              Month_Name_September  Count_of_question_mark  \
# FOLLOWERS                                0.385464               -0.044039
# FOLLOWING                               -0.009462                0.030003
# Tagged_Users_Count                       0.051475                0.024505
# number_of_tags                          -0.003276                0.133918
# number_of_mentions                       0.005201                0.155970
# Text_Length                             -0.011648                0.194904
# TYPE(1 PHOTO,2 VIDEO)_video             -0.012081               -0.001586
# Post_Timing_Evening                      0.000467               -0.004083
# Post_Timing_Morning                     -0.000958               -0.018319
# Post_Timing_Night                        0.002573                0.036754
# Day_of_Week_Monday                      -0.004154                0.022352
# Day_of_Week_Saturday                    -0.007693               -0.008930
# Day_of_Week_Sunday                       0.010114                0.001718
# Day_of_Week_Thursday                    -0.001058               -0.011805
# Day_of_Week_Wednesday                   -0.004219               -0.015047
# Day_of_Week_Tuesday                      0.003339                0.005821
# Month_Name_August                       -0.001090               -0.015207
# Month_Name_December                     -0.000458                0.008376
# Month_Name_February                     -0.001240               -0.011848
# Month_Name_January                      -0.001024               -0.009331
# Month_Name_July                         -0.000793               -0.011062
# Month_Name_March                        -0.000591                0.001284
# Month_Name_May                          -0.009905                0.038091
# Month_Name_November                     -0.000793               -0.011062
# Month_Name_October                      -0.001024               -0.014284
# Month_Name_September                     1.000000               -0.018759
# Count_of_question_mark                  -0.018759                1.000000
# keywords_for_engagement                  0.002306                0.086011
# emojis_for_engagement                   -0.009578                0.249154
#
#                              keywords_for_engagement  emojis_for_engagement
# FOLLOWERS                                   0.002734              -0.009812
# FOLLOWING                                   0.052091              -0.024599
# Tagged_Users_Count                          0.067118               0.041293
# number_of_tags                              0.396670               0.075297
# number_of_mentions                          0.094327               0.015842
# Text_Length                                 0.326648               0.079328
# TYPE(1 PHOTO,2 VIDEO)_video                -0.047633              -0.031936
# Post_Timing_Evening                         0.021948              -0.002971
# Post_Timing_Morning                         0.017968               0.001938
# Post_Timing_Night                          -0.022956               0.006212
# Day_of_Week_Monday                          0.010574               0.018668
# Day_of_Week_Saturday                       -0.004609               0.001137
# Day_of_Week_Sunday                         -0.014689               0.012533
# Day_of_Week_Thursday                       -0.001465              -0.003882
# Day_of_Week_Wednesday                       0.003839              -0.011085
# Day_of_Week_Tuesday                        -0.001096              -0.004634
# Month_Name_August                           0.011779              -0.007598
# Month_Name_December                        -0.005030               0.008250
# Month_Name_February                        -0.012022              -0.008645
# Month_Name_January                         -0.009306              -0.007137
# Month_Name_July                             0.021421              -0.005527
# Month_Name_March                            0.010350              -0.004119
# Month_Name_May                              0.008510               0.013101
# Month_Name_November                        -0.003692              -0.005527
# Month_Name_October                         -0.005415              -0.007137
# Month_Name_September                        0.002306              -0.009578
# Count_of_question_mark                      0.086011               0.249154
# keywords_for_engagement                     1.000000               0.072951
# emojis_for_engagement                       0.072951               1.000000
#
# [29 rows x 29 columns]

# %% [markdown]
# # **Re-run regression with new variables**

# %% [markdown]
# ## Regression Analysis for Predicting Likes with New Variables

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data_new[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = data_new[['LIKES']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.439
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     512.8
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:43:09   Log-Likelihood:            -1.9192e+05
# No. Observations:               19675   AIC:                         3.839e+05
# Df Residuals:                   19644   BIC:                         3.842e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         357.7034    101.561      3.522      0.000     158.636     556.771
# FOLLOWERS                       0.0482      0.000    114.164      0.000       0.047       0.049
# FOLLOWING                      -0.1533      0.014    -11.325      0.000      -0.180      -0.127
# Tagged_Users_Count            -20.3523     16.318     -1.247      0.212     -52.337      11.633
# number_of_tags                 -8.6958      4.538     -1.916      0.055     -17.590       0.198
# number_of_mentions            -55.8090     18.631     -2.995      0.003     -92.328     -19.290
# Text_Length                    -0.6809      0.218     -3.125      0.002      -1.108      -0.254
# TYPE(1 PHOTO,2 VIDEO)_video  -855.9036    102.801     -8.326      0.000   -1057.403    -654.404
# Post_Timing_Evening          -131.4508     83.847     -1.568      0.117    -295.798      32.896
# Post_Timing_Morning          -426.5286    104.733     -4.073      0.000    -631.813    -221.244
# Post_Timing_Night            -124.7477     77.387     -1.612      0.107    -276.432      26.937
# Day_of_Week_Monday             75.0344    118.265      0.634      0.526    -156.776     306.844
# Day_of_Week_Saturday         -234.8193    108.345     -2.167      0.030    -447.185     -22.453
# Day_of_Week_Sunday           -213.4592    106.386     -2.006      0.045    -421.985      -4.934
# Day_of_Week_Thursday          -41.9651    106.433     -0.394      0.693    -250.582     166.652
# Day_of_Week_Wednesday         -11.3975    117.618     -0.097      0.923    -241.939     219.144
# Day_of_Week_Tuesday           -99.1056    115.824     -0.856      0.392    -326.130     127.919
# Month_Name_August           -4.236e+04   1112.001    -38.093      0.000   -4.45e+04   -4.02e+04
# Month_Name_December         -1.605e+04   2415.306     -6.646      0.000   -2.08e+04   -1.13e+04
# Month_Name_February         -1.752e+04    913.154    -19.184      0.000   -1.93e+04   -1.57e+04
# Month_Name_January          -3.184e+04   1136.626    -28.015      0.000   -3.41e+04   -2.96e+04
# Month_Name_July             -4.036e+04   1465.926    -27.529      0.000   -4.32e+04   -3.75e+04
# Month_Name_March              130.0664   1867.731      0.070      0.944   -3530.844    3790.977
# Month_Name_May               -613.2131    138.556     -4.426      0.000    -884.795    -341.631
# Month_Name_November         -3.877e+04   1462.774    -26.506      0.000   -4.16e+04   -3.59e+04
# Month_Name_October          -3.697e+04   1168.695    -31.632      0.000   -3.93e+04   -3.47e+04
# Month_Name_September        -3.819e+04    920.741    -41.477      0.000      -4e+04   -3.64e+04
# Count_of_exclamation_markt     31.1392     19.443      1.602      0.109      -6.971      69.249
# Count_of_question_mark         31.6649      9.433      3.357      0.001      13.174      50.155
# keywords_for_engagement       119.4348     34.704      3.442      0.001      51.413     187.457
# emojis_for_engagement        -106.0400     85.759     -1.236      0.216    -274.135      62.055
# ==============================================================================
# Omnibus:                    31724.010   Durbin-Watson:                   0.561
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         42268170.761
# Skew:                          10.328   Prob(JB):                         0.00
# Kurtosis:                     229.126   Cond. No.                     9.79e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.79e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Standardized Regression Analysis for Predicting Likes with New Variables

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data_new[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = data_new[['LIKES']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)

# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.439
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     512.8
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:44:17   Log-Likelihood:                -22228.
# No. Observations:               19675   AIC:                         4.452e+04
# Df Residuals:                   19644   BIC:                         4.476e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        1.887e-16      0.005   3.53e-14      1.000      -0.010       0.010
# FOLLOWERS                       0.8919      0.008    114.164      0.000       0.877       0.907
# FOLLOWING                      -0.0620      0.005    -11.325      0.000      -0.073      -0.051
# Tagged_Users_Count             -0.0069      0.006     -1.247      0.212      -0.018       0.004
# number_of_tags                 -0.0137      0.007     -1.916      0.055      -0.028       0.000
# number_of_mentions             -0.0171      0.006     -2.995      0.003      -0.028      -0.006
# Text_Length                    -0.0225      0.007     -3.125      0.002      -0.037      -0.008
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0453      0.005     -8.326      0.000      -0.056      -0.035
# Post_Timing_Evening            -0.0103      0.007     -1.568      0.117      -0.023       0.003
# Post_Timing_Morning            -0.0248      0.006     -4.073      0.000      -0.037      -0.013
# Post_Timing_Night              -0.0108      0.007     -1.612      0.107      -0.024       0.002
# Day_of_Week_Monday              0.0048      0.008      0.634      0.526      -0.010       0.020
# Day_of_Week_Saturday           -0.0150      0.007     -2.167      0.030      -0.028      -0.001
# Day_of_Week_Sunday             -0.0140      0.007     -2.006      0.045      -0.028      -0.000
# Day_of_Week_Thursday           -0.0028      0.007     -0.394      0.693      -0.016       0.011
# Day_of_Week_Wednesday          -0.0006      0.007     -0.097      0.923      -0.014       0.012
# Day_of_Week_Tuesday            -0.0058      0.007     -0.856      0.392      -0.019       0.007
# Month_Name_August              -0.2235      0.006    -38.093      0.000      -0.235      -0.212
# Month_Name_December            -0.0356      0.005     -6.646      0.000      -0.046      -0.025
# Month_Name_February            -0.1051      0.005    -19.184      0.000      -0.116      -0.094
# Month_Name_January             -0.1578      0.006    -28.015      0.000      -0.169      -0.147
# Month_Name_July                -0.1550      0.006    -27.529      0.000      -0.166      -0.144
# Month_Name_March                0.0004      0.005      0.070      0.944      -0.010       0.011
# Month_Name_May                 -0.0275      0.006     -4.426      0.000      -0.040      -0.015
# Month_Name_November            -0.1489      0.006    -26.506      0.000      -0.160      -0.138
# Month_Name_October             -0.1832      0.006    -31.632      0.000      -0.195      -0.172
# Month_Name_September           -0.2539      0.006    -41.477      0.000      -0.266      -0.242
# Count_of_exclamation_markt      0.0089      0.006      1.602      0.109      -0.002       0.020
# Count_of_question_mark          0.0190      0.006      3.357      0.001       0.008       0.030
# keywords_for_engagement         0.0203      0.006      3.442      0.001       0.009       0.032
# emojis_for_engagement          -0.0069      0.006     -1.236      0.216      -0.018       0.004
# ==============================================================================
# Omnibus:                    31724.010   Durbin-Watson:                   0.561
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         42268170.761
# Skew:                          10.328   Prob(JB):                         0.00
# Kurtosis:                     229.126   Cond. No.                         3.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Regression Analysis for Predicting Comments with New Variables

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data_new[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = data_new[['COMMENTS']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     57.88
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:44:37   Log-Likelihood:            -1.4720e+05
# No. Observations:               19675   AIC:                         2.945e+05
# Df Residuals:                   19644   BIC:                         2.947e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         -11.0620     10.458     -1.058      0.290     -31.561       9.437
# FOLLOWERS                       0.0016   4.34e-05     36.960      0.000       0.002       0.002
# FOLLOWING                      -0.0007      0.001     -0.511      0.609      -0.003       0.002
# Tagged_Users_Count             -9.8808      1.680     -5.880      0.000     -13.175      -6.587
# number_of_tags                 -2.5712      0.467     -5.503      0.000      -3.487      -1.655
# number_of_mentions             -0.9805      1.919     -0.511      0.609      -4.741       2.780
# Text_Length                     0.0055      0.022      0.246      0.806      -0.038       0.049
# TYPE(1 PHOTO,2 VIDEO)_video   -14.3965     10.586     -1.360      0.174     -35.146       6.353
# Post_Timing_Evening           -31.3891      8.634     -3.635      0.000     -48.313     -14.465
# Post_Timing_Morning           -23.1280     10.785     -2.144      0.032     -44.267      -1.989
# Post_Timing_Night             -31.5853      7.969     -3.964      0.000     -47.205     -15.965
# Day_of_Week_Monday             10.6459     12.178      0.874      0.382     -13.225      34.517
# Day_of_Week_Saturday          -30.6484     11.157     -2.747      0.006     -52.517      -8.780
# Day_of_Week_Sunday            -23.1734     10.955     -2.115      0.034     -44.646      -1.700
# Day_of_Week_Thursday          -17.3801     10.960     -1.586      0.113     -38.863       4.102
# Day_of_Week_Wednesday         -16.7956     12.112     -1.387      0.166     -40.536       6.945
# Day_of_Week_Tuesday           -13.1081     11.927     -1.099      0.272     -36.486      10.270
# Month_Name_August           -1703.8461    114.509    -14.880      0.000   -1928.293   -1479.399
# Month_Name_December          -548.9173    248.718     -2.207      0.027   -1036.425     -61.410
# Month_Name_February          -758.8630     94.033     -8.070      0.000    -943.175    -574.551
# Month_Name_January          -1322.6885    117.045    -11.301      0.000   -1552.106   -1093.271
# Month_Name_July             -1746.7899    150.955    -11.572      0.000   -2042.674   -1450.906
# Month_Name_March              -42.1912    192.331     -0.219      0.826    -419.176     334.793
# Month_Name_May                -38.6453     14.268     -2.709      0.007     -66.612     -10.679
# Month_Name_November         -1677.6718    150.630    -11.138      0.000   -1972.919   -1382.424
# Month_Name_October          -1668.2151    120.347    -13.862      0.000   -1904.105   -1432.325
# Month_Name_September        -1688.9122     94.814    -17.813      0.000   -1874.755   -1503.069
# Count_of_exclamation_markt     -2.6444      2.002     -1.321      0.187      -6.569       1.280
# Count_of_question_mark          1.9578      0.971      2.015      0.044       0.054       3.862
# keywords_for_engagement        53.8903      3.574     15.080      0.000      46.886      60.895
# emojis_for_engagement           4.8714      8.831      0.552      0.581     -12.438      22.181
# ==============================================================================
# Omnibus:                    52749.626   Durbin-Watson:                   0.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1678252288.717
# Skew:                          32.621   Prob(JB):                         0.00
# Kurtosis:                    1432.305   Cond. No.                     9.79e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.79e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Standardized Regression Analysis for Predicting Comments with New Variables

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data_new[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = data_new[['COMMENTS']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)

# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     57.88
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:44:51   Log-Likelihood:                -27084.
# No. Observations:               19675   AIC:                         5.423e+04
# Df Residuals:                   19644   BIC:                         5.448e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -4.851e-16      0.007  -7.09e-14      1.000      -0.013       0.013
# FOLLOWERS                       0.3696      0.010     36.960      0.000       0.350       0.389
# FOLLOWING                      -0.0036      0.007     -0.511      0.609      -0.017       0.010
# Tagged_Users_Count             -0.0415      0.007     -5.880      0.000      -0.055      -0.028
# number_of_tags                 -0.0504      0.009     -5.503      0.000      -0.068      -0.032
# number_of_mentions             -0.0037      0.007     -0.511      0.609      -0.018       0.011
# Text_Length                     0.0023      0.009      0.246      0.806      -0.016       0.020
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0095      0.007     -1.360      0.174      -0.023       0.004
# Post_Timing_Evening            -0.0305      0.008     -3.635      0.000      -0.047      -0.014
# Post_Timing_Morning            -0.0167      0.008     -2.144      0.032      -0.032      -0.001
# Post_Timing_Night              -0.0341      0.009     -3.964      0.000      -0.051      -0.017
# Day_of_Week_Monday              0.0085      0.010      0.874      0.382      -0.011       0.028
# Day_of_Week_Saturday           -0.0243      0.009     -2.747      0.006      -0.042      -0.007
# Day_of_Week_Sunday             -0.0189      0.009     -2.115      0.034      -0.036      -0.001
# Day_of_Week_Thursday           -0.0142      0.009     -1.586      0.113      -0.032       0.003
# Day_of_Week_Wednesday          -0.0117      0.008     -1.387      0.166      -0.028       0.005
# Day_of_Week_Tuesday            -0.0095      0.009     -1.099      0.272      -0.026       0.007
# Month_Name_August              -0.1117      0.008    -14.880      0.000      -0.126      -0.097
# Month_Name_December            -0.0151      0.007     -2.207      0.027      -0.029      -0.002
# Month_Name_February            -0.0566      0.007     -8.070      0.000      -0.070      -0.043
# Month_Name_January             -0.0815      0.007    -11.301      0.000      -0.096      -0.067
# Month_Name_July                -0.0834      0.007    -11.572      0.000      -0.097      -0.069
# Month_Name_March               -0.0015      0.007     -0.219      0.826      -0.015       0.012
# Month_Name_May                 -0.0215      0.008     -2.709      0.007      -0.037      -0.006
# Month_Name_November            -0.0801      0.007    -11.138      0.000      -0.094      -0.066
# Month_Name_October             -0.1028      0.007    -13.862      0.000      -0.117      -0.088
# Month_Name_September           -0.1395      0.008    -17.813      0.000      -0.155      -0.124
# Count_of_exclamation_markt     -0.0094      0.007     -1.321      0.187      -0.023       0.005
# Count_of_question_mark          0.0146      0.007      2.015      0.044       0.000       0.029
# keywords_for_engagement         0.1139      0.008     15.080      0.000       0.099       0.129
# emojis_for_engagement           0.0039      0.007      0.552      0.581      -0.010       0.018
# ==============================================================================
# Omnibus:                    52749.626   Durbin-Watson:                   0.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1678252288.717
# Skew:                          32.621   Prob(JB):                         0.00
# Kurtosis:                    1432.305   Cond. No.                         3.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19675 entries, 0 to 19680
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   USERNAME                     19675 non-null  object
#  1   FOLLOWERS                    19675 non-null  int64
#  2   FOLLOWING                    19675 non-null  int64
#  3   LIKES                        19675 non-null  int64
#  4   COMMENTS                     19675 non-null  int64
#  5   TEXT                         19675 non-null  object
#  6   DATE                         19675 non-null  datetime64[ns]
#  7   Tagged_Users_Count           19675 non-null  int32
#  8   LINK                         19675 non-null  object
#  9   number_of_tags               19675 non-null  int64
#  10  number_of_mentions           19675 non-null  int64
#  11  Month                        19675 non-null  int32
#  12  Text_Length                  19675 non-null  int64
#  13  Month_Name_August            19675 non-null  int32
#  14  Month_Name_December          19675 non-null  int32
#  15  Month_Name_February          19675 non-null  int32
#  16  Month_Name_January           19675 non-null  int32
#  17  Month_Name_July              19675 non-null  int32
#  18  Month_Name_March             19675 non-null  int32
#  19  Month_Name_May               19675 non-null  int32
#  20  Month_Name_November          19675 non-null  int32
#  21  Month_Name_October           19675 non-null  int32
#  22  Month_Name_September         19675 non-null  int32
#  23  Day_of_Week_Monday           19675 non-null  int32
#  24  Day_of_Week_Saturday         19675 non-null  int32
#  25  Day_of_Week_Sunday           19675 non-null  int32
#  26  Day_of_Week_Thursday         19675 non-null  int32
#  27  Day_of_Week_Tuesday          19675 non-null  int32
#  28  Day_of_Week_Wednesday        19675 non-null  int32
#  29  Post_Timing_Evening          19675 non-null  int32
#  30  Post_Timing_Morning          19675 non-null  int32
#  31  Post_Timing_Night            19675 non-null  int32
#  32  TYPE(1 PHOTO,2 VIDEO)_video  19675 non-null  int32
#  33  Count_of_question_mark       19675 non-null  int64
#  34  Count_of_exclamation_markt   19675 non-null  int64
#  35  keywords_for_engagement      19675 non-null  int64
#  36  emojis_for_engagement        19675 non-null  int64
# dtypes: datetime64[ns](1), int32(22), int64(11), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# # **Weekend Analysis**

# %%
# Extract the day of the week (e.g., Monday, Tuesday) from the 'DATE' column and store it in a new column called 'Day_of_Week'
data['Day_of_Week'] = data['DATE'].dt.day_name()

# %%
# Create a new column 'Is_Weekend' to indicate whether the post was made on a weekend (1 for Saturday/Sunday, 0 for weekdays)
data['Is_Weekend'] = data['Day_of_Week'].apply(lambda x: 1 if x in ['Saturday', 'Sunday'] else 0)

# %%
data.head()
# Out:
#      USERNAME  FOLLOWERS  FOLLOWING  LIKES  COMMENTS  \
# 0  georgiou82    1134619        915  18560        95
# 1  georgiou82    1134619        915  17710        86
# 2  georgiou82    1134619        915  11959        79
# 3  georgiou82    1134619        915  13608        37
# 4  georgiou82    1134619        915  15842        62
#
#                                                 TEXT                DATE  \
# 0  Every day is a #newday and every experience is... 2017-02-11 11:05:10
# 1  #goodnight !!! The #weekend is ahead!!! Have a... 2017-02-11 00:33:10
# 2  #tb #2007 #stous31dromous #megatv #greece #new... 2017-02-09 15:51:47
# 3  Cold weather brings people together.... #filmi... 2017-02-08 18:21:57
# 4  The youngest hearts might be the oldest souls.... 2017-02-08 13:03:14
#
#    Tagged_Users_Count                                     LINK  \
# 0                   1  https://www.instagram.com/p/BQXZpSQjiPj
# 1                   1  https://www.instagram.com/p/BQWRUV6j8b-
# 2                   3  https://www.instagram.com/p/BQSw2wMj0Bw
# 3                   3  https://www.instagram.com/p/BQQdPrLDeRz
# 4                   0  https://www.instagram.com/p/BQP4xY7jAXb
#
#    number_of_tags  ...  Post_Timing_Evening  Post_Timing_Morning  \
# 0               2  ...                    0                    1
# 1               3  ...                    0                    0
# 2               7  ...                    0                    0
# 3               2  ...                    1                    0
# 4               4  ...                    0                    0
#
#    Post_Timing_Night  TYPE(1 PHOTO,2 VIDEO)_video  Count_of_question_mark  \
# 0                  0                            0                       0
# 1                  1                            0                       0
# 2                  0                            0                       0
# 3                  0                            0                       0
# 4                  0                            0                       0
#
#    Count_of_exclamation_markt  keywords_for_engagement  emojis_for_engagement  \
# 0                           0                        0                      0
# 1                          10                        0                      0
# 2                           0                        0                      0
# 3                           0                        0                      0
# 4                           0                        0                      0
#
#    Day_of_Week  Is_Weekend
# 0     Saturday           1
# 1     Saturday           1
# 2     Thursday           0
# 3    Wednesday           0
# 4    Wednesday           0
#
# [5 rows x 39 columns]

# %% [markdown]
# # **Regression Analysis for Question 3: Weekend vs. Weekday Impact on Likes and Comments**

# %% [markdown]
# ## Regression Analysis for Predicting Likes with Weekend Indicator

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night','Is_Weekend','Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September']]
DV = data[['LIKES']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     730.4
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:46:21   Log-Likelihood:            -1.9194e+05
# No. Observations:               19675   AIC:                         3.839e+05
# Df Residuals:                   19653   BIC:                         3.841e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         388.2588     76.037      5.106      0.000     239.219     537.298
# FOLLOWERS                       0.0482      0.000    114.822      0.000       0.047       0.049
# FOLLOWING                      -0.1535      0.014    -11.357      0.000      -0.180      -0.127
# Tagged_Users_Count            -20.1392     16.318     -1.234      0.217     -52.123      11.845
# number_of_tags                 -5.4627      4.326     -1.263      0.207     -13.941       3.016
# number_of_mentions            -46.2658     18.511     -2.499      0.012     -82.548      -9.983
# Text_Length                    -0.4535      0.211     -2.152      0.031      -0.867      -0.040
# TYPE(1 PHOTO,2 VIDEO)_video  -880.9990    102.589     -8.588      0.000   -1082.083    -679.915
# Post_Timing_Evening          -127.6561     83.839     -1.523      0.128    -291.988      36.676
# Post_Timing_Morning          -430.0591    104.755     -4.105      0.000    -635.387    -224.731
# Post_Timing_Night            -135.1526     77.244     -1.750      0.080    -286.557      16.252
# Is_Weekend                   -204.1429     65.650     -3.110      0.002    -332.823     -75.463
# Month_Name_August           -4.245e+04   1111.727    -38.179      0.000   -4.46e+04   -4.03e+04
# Month_Name_December         -1.592e+04   2415.413     -6.590      0.000   -2.07e+04   -1.12e+04
# Month_Name_February         -1.758e+04    913.324    -19.244      0.000   -1.94e+04   -1.58e+04
# Month_Name_January          -3.189e+04   1136.554    -28.061      0.000   -3.41e+04   -2.97e+04
# Month_Name_July             -4.035e+04   1465.390    -27.537      0.000   -4.32e+04   -3.75e+04
# Month_Name_March              251.5574   1868.170      0.135      0.893   -3410.215    3913.330
# Month_Name_May               -534.9068    121.486     -4.403      0.000    -773.030    -296.783
# Month_Name_November         -3.885e+04   1462.489    -26.561      0.000   -4.17e+04    -3.6e+04
# Month_Name_October          -3.708e+04   1168.200    -31.738      0.000   -3.94e+04   -3.48e+04
# Month_Name_September        -3.826e+04    920.324    -41.576      0.000   -4.01e+04   -3.65e+04
# ==============================================================================
# Omnibus:                    31784.719   Durbin-Watson:                   0.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         42717792.069
# Skew:                          10.368   Prob(JB):                         0.00
# Kurtosis:                     230.328   Cond. No.                     9.78e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.78e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Regression Analysis for Predicting Comments with Weekend Indicator

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = data[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night','Is_Weekend','Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September']]
DV = data[['COMMENTS']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     70.24
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):          1.13e-288
# Time:                        20:46:23   Log-Likelihood:            -1.4732e+05
# No. Observations:               19675   AIC:                         2.947e+05
# Df Residuals:                   19653   BIC:                         2.949e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         -14.4783      7.873     -1.839      0.066     -29.909       0.953
# FOLLOWERS                       0.0016   4.35e-05     37.025      0.000       0.002       0.002
# FOLLOWING                      -0.0005      0.001     -0.367      0.713      -0.003       0.002
# Tagged_Users_Count             -9.5798      1.689     -5.670      0.000     -12.891      -6.268
# number_of_tags                 -0.6159      0.448     -1.375      0.169      -1.494       0.262
# number_of_mentions              0.4155      1.917      0.217      0.828      -3.341       4.172
# Text_Length                     0.0406      0.022      1.863      0.063      -0.002       0.083
# TYPE(1 PHOTO,2 VIDEO)_video   -24.7143     10.622     -2.327      0.020     -45.533      -3.895
# Post_Timing_Evening           -30.0861      8.680     -3.466      0.001     -47.100     -13.072
# Post_Timing_Morning           -22.2281     10.846     -2.049      0.040     -43.487      -0.970
# Post_Timing_Night             -35.5408      7.997     -4.444      0.000     -51.216     -19.865
# Is_Weekend                    -19.4555      6.797     -2.862      0.004     -32.778      -6.133
# Month_Name_August           -1708.4400    115.102    -14.843      0.000   -1934.051   -1482.830
# Month_Name_December          -554.8293    250.079     -2.219      0.027   -1045.006     -64.653
# Month_Name_February          -770.7046     94.561     -8.150      0.000    -956.052    -585.357
# Month_Name_January          -1331.8894    117.673    -11.319      0.000   -1562.538   -1101.241
# Month_Name_July             -1717.6942    151.719    -11.322      0.000   -2015.076   -1420.312
# Month_Name_March               -0.0150    193.421  -7.77e-05      1.000    -379.136     379.106
# Month_Name_May                -23.3478     12.578     -1.856      0.063     -48.002       1.306
# Month_Name_November         -1675.6841    151.418    -11.067      0.000   -1972.477   -1378.891
# Month_Name_October          -1678.0502    120.949    -13.874      0.000   -1915.121   -1440.979
# Month_Name_September        -1691.1403     95.286    -17.748      0.000   -1877.908   -1504.372
# ==============================================================================
# Omnibus:                    52837.120   Durbin-Watson:                   0.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1678864787.510
# Skew:                          32.770   Prob(JB):                         0.00
# Kurtosis:                    1432.553   Cond. No.                     9.78e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.78e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # **Micro and Macro Influencers Analysis**

# %%
# Divide data into micro and macro influencers
micro_influencers = data_new[data_new['FOLLOWERS'] < 50000]
macro_influencers = data_new[data_new['FOLLOWERS'] >= 50000]

# %% [markdown]
# ## Regression for micro influencers

# %% [markdown]
# ### Regression Analysis for Predicting Likes (Micro Influencers)

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = micro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = micro_influencers[['LIKES']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     56.51
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):          5.99e-268
# Time:                        20:46:36   Log-Likelihood:            -1.1405e+05
# No. Observations:               13134   AIC:                         2.282e+05
# Df Residuals:                   13108   BIC:                         2.284e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         711.6895     59.246     12.012      0.000     595.558     827.820
# FOLLOWERS                       0.0249      0.001     17.326      0.000       0.022       0.028
# FOLLOWING                      -0.1122      0.005    -21.628      0.000      -0.122      -0.102
# Tagged_Users_Count             32.9064      8.851      3.718      0.000      15.557      50.256
# number_of_tags                 14.4805      1.840      7.870      0.000      10.874      18.087
# number_of_mentions            -45.3111      7.541     -6.009      0.000     -60.092     -30.530
# Text_Length                    -0.6339      0.085     -7.441      0.000      -0.801      -0.467
# TYPE(1 PHOTO,2 VIDEO)_video  -512.8156     43.455    -11.801      0.000    -597.994    -427.637
# Post_Timing_Evening             3.7207     35.361      0.105      0.916     -65.591      73.033
# Post_Timing_Morning          -150.7177     43.803     -3.441      0.001    -236.578     -64.857
# Post_Timing_Night             -40.2358     32.974     -1.220      0.222    -104.869      24.398
# Day_of_Week_Monday             41.4211     49.600      0.835      0.404     -55.802     138.644
# Day_of_Week_Saturday          -34.7871     45.495     -0.765      0.445    -123.964      54.390
# Day_of_Week_Sunday            -56.7248     44.805     -1.266      0.206    -144.548      31.099
# Day_of_Week_Thursday          -40.0004     44.912     -0.891      0.373    -128.034      48.033
# Day_of_Week_Wednesday         -10.6292     49.395     -0.215      0.830    -107.450      86.191
# Day_of_Week_Tuesday           -18.6578     48.724     -0.383      0.702    -114.164      76.849
# Month_Name_August           -3.308e-09    5.4e-09     -0.612      0.540   -1.39e-08    7.28e-09
# Month_Name_December         -1251.2716   1013.388     -1.235      0.217   -3237.659     735.116
# Month_Name_February          -302.3779    452.953     -0.668      0.504   -1190.231     585.475
# Month_Name_January           -921.5362   1012.674     -0.910      0.363   -2906.525    1063.452
# Month_Name_July             -8.535e-10    1.4e-09     -0.612      0.541   -3.59e-09    1.88e-09
# Month_Name_March              189.5511    640.456      0.296      0.767   -1065.836    1444.939
# Month_Name_May               -294.7210     57.349     -5.139      0.000    -407.133    -182.309
# Month_Name_November          6.943e-11   1.14e-10      0.610      0.542   -1.54e-10    2.93e-10
# Month_Name_October                   0          0        nan        nan           0           0
# Month_Name_September                 0          0        nan        nan           0           0
# Count_of_exclamation_markt    125.0505      8.722     14.338      0.000     107.954     142.147
# Count_of_question_mark          3.8795      3.639      1.066      0.286      -3.253      11.012
# keywords_for_engagement       -11.3501     13.921     -0.815      0.415     -38.638      15.938
# emojis_for_engagement        -105.4646     34.770     -3.033      0.002    -173.619     -37.310
# ==============================================================================
# Omnibus:                    14213.349   Durbin-Watson:                   0.500
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2772622.329
# Skew:                           5.157   Prob(JB):                         0.00
# Kurtosis:                      73.428   Cond. No.                     1.05e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.15e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Standardized Regression Analysis for Predicting Likes (Micro Influencers)

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = micro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = micro_influencers[['LIKES']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)
# Fill missing values for specific columns
IVs_with_const['Month_Name_August'] = IVs_with_const['Month_Name_August'].fillna(0)  # Replace NaN with 0
IVs_with_const['Month_Name_July'] = IVs_with_const['Month_Name_July'].fillna(0)
IVs_with_const['Month_Name_November'] = IVs_with_const['Month_Name_November'].fillna(0)
IVs_with_const['Month_Name_September'] = IVs_with_const['Month_Name_September'].fillna(0)
IVs_with_const['Month_Name_October'] = IVs_with_const['Month_Name_October'].fillna(0)
# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     56.51
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):          5.99e-268
# Time:                        20:46:49   Log-Likelihood:                -17964.
# No. Observations:               13134   AIC:                         3.598e+04
# Df Residuals:                   13108   BIC:                         3.617e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -1.279e-16      0.008  -1.54e-14      1.000      -0.016       0.016
# FOLLOWERS                       0.1521      0.009     17.326      0.000       0.135       0.169
# FOLLOWING                      -0.1837      0.008    -21.628      0.000      -0.200      -0.167
# Tagged_Users_Count              0.0327      0.009      3.718      0.000       0.015       0.050
# number_of_tags                  0.0873      0.011      7.870      0.000       0.066       0.109
# number_of_mentions             -0.0533      0.009     -6.009      0.000      -0.071      -0.036
# Text_Length                    -0.0824      0.011     -7.441      0.000      -0.104      -0.061
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0995      0.008    -11.801      0.000      -0.116      -0.083
# Post_Timing_Evening             0.0011      0.010      0.105      0.916      -0.019       0.021
# Post_Timing_Morning            -0.0329      0.010     -3.441      0.001      -0.052      -0.014
# Post_Timing_Night              -0.0129      0.011     -1.220      0.222      -0.034       0.008
# Day_of_Week_Monday              0.0100      0.012      0.835      0.404      -0.013       0.033
# Day_of_Week_Saturday           -0.0082      0.011     -0.765      0.445      -0.029       0.013
# Day_of_Week_Sunday             -0.0138      0.011     -1.266      0.206      -0.035       0.008
# Day_of_Week_Thursday           -0.0097      0.011     -0.891      0.373      -0.031       0.012
# Day_of_Week_Wednesday          -0.0022      0.010     -0.215      0.830      -0.022       0.018
# Day_of_Week_Tuesday            -0.0040      0.010     -0.383      0.702      -0.025       0.016
# Month_Name_August           -3.566e-17   2.31e-18    -15.452      0.000   -4.02e-17   -3.11e-17
# Month_Name_December            -0.0103      0.008     -1.235      0.217      -0.027       0.006
# Month_Name_February            -0.0055      0.008     -0.668      0.504      -0.022       0.011
# Month_Name_January             -0.0076      0.008     -0.910      0.363      -0.024       0.009
# Month_Name_July             -1.167e-17   3.83e-18     -3.048      0.002   -1.92e-17   -4.17e-18
# Month_Name_March                0.0025      0.008      0.296      0.767      -0.014       0.019
# Month_Name_May                 -0.0499      0.010     -5.139      0.000      -0.069      -0.031
# Month_Name_November         -8.282e-18    2.6e-18     -3.183      0.001   -1.34e-17   -3.18e-18
# Month_Name_October          -8.391e-18   1.85e-18     -4.536      0.000    -1.2e-17   -4.76e-18
# Month_Name_September                 0          0        nan        nan           0           0
# Count_of_exclamation_markt      0.1227      0.009     14.338      0.000       0.106       0.140
# Count_of_question_mark          0.0096      0.009      1.066      0.286      -0.008       0.027
# keywords_for_engagement        -0.0075      0.009     -0.815      0.415      -0.025       0.010
# emojis_for_engagement          -0.0266      0.009     -3.033      0.002      -0.044      -0.009
# ==============================================================================
# Omnibus:                    14213.349   Durbin-Watson:                   0.500
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2772622.329
# Skew:                           5.157   Prob(JB):                         0.00
# Kurtosis:                      73.428   Cond. No.                     1.23e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.9e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Regression Analysis for Predicting Comments (Micro Influencers)

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = micro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = micro_influencers[['COMMENTS']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     8.063
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):           2.79e-29
# Time:                        20:46:49   Log-Likelihood:                -76757.
# No. Observations:               13134   AIC:                         1.536e+05
# Df Residuals:                   13108   BIC:                         1.538e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           9.8150      3.462      2.835      0.005       3.029      16.601
# FOLLOWERS                       0.0002    8.4e-05      1.877      0.061   -7.02e-06       0.000
# FOLLOWING                      -0.0013      0.000     -4.261      0.000      -0.002      -0.001
# Tagged_Users_Count             -0.0596      0.517     -0.115      0.908      -1.074       0.954
# number_of_tags                 -0.4118      0.108     -3.830      0.000      -0.623      -0.201
# number_of_mentions             -0.2935      0.441     -0.666      0.505      -1.157       0.570
# Text_Length                     0.0227      0.005      4.554      0.000       0.013       0.032
# TYPE(1 PHOTO,2 VIDEO)_video    -1.7008      2.539     -0.670      0.503      -6.678       3.277
# Post_Timing_Evening            -0.1125      2.066     -0.054      0.957      -4.163       3.938
# Post_Timing_Morning            -2.3826      2.560     -0.931      0.352      -7.400       2.635
# Post_Timing_Night              -0.6587      1.927     -0.342      0.732      -4.436       3.118
# Day_of_Week_Monday              7.5420      2.899      2.602      0.009       1.861      13.224
# Day_of_Week_Saturday           -1.9017      2.659     -0.715      0.474      -7.113       3.310
# Day_of_Week_Sunday             -2.7484      2.618     -1.050      0.294      -7.881       2.384
# Day_of_Week_Thursday           -2.7268      2.625     -1.039      0.299      -7.871       2.418
# Day_of_Week_Wednesday          -1.4176      2.887     -0.491      0.623      -7.076       4.240
# Day_of_Week_Tuesday            -0.6545      2.847     -0.230      0.818      -6.236       4.927
# Month_Name_August           -3.316e-11   3.16e-10     -0.105      0.916   -6.52e-10    5.86e-10
# Month_Name_December           -20.1699     59.220     -0.341      0.733    -136.250      95.911
# Month_Name_February            -4.4284     26.470     -0.167      0.867     -56.313      47.456
# Month_Name_January            -22.4290     59.179     -0.379      0.705    -138.428      93.570
# Month_Name_July             -8.532e-12   8.15e-11     -0.105      0.917   -1.68e-10    1.51e-10
# Month_Name_March              -14.2691     37.427     -0.381      0.703     -87.631      59.093
# Month_Name_May                -11.6615      3.351     -3.480      0.001     -18.231      -5.092
# Month_Name_November          6.934e-13   6.65e-12      0.104      0.917   -1.23e-11    1.37e-11
# Month_Name_October                   0          0        nan        nan           0           0
# Month_Name_September                 0          0        nan        nan           0           0
# Count_of_exclamation_markt      2.2737      0.510      4.461      0.000       1.275       3.273
# Count_of_question_mark          0.1218      0.213      0.573      0.567      -0.295       0.539
# keywords_for_engagement         6.9581      0.814      8.553      0.000       5.363       8.553
# emojis_for_engagement          -4.5091      2.032     -2.219      0.026      -8.492      -0.526
# ==============================================================================
# Omnibus:                    33389.308   Durbin-Watson:                   1.551
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        722947730.823
# Skew:                          28.409   Prob(JB):                         0.00
# Kurtosis:                    1150.967   Cond. No.                     1.05e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.15e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Standardized Regression Analysis for Predicting Comments (Micro Influencers)

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = micro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = micro_influencers[['COMMENTS']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)
# Fill missing values for specific columns
IVs_with_const['Month_Name_August'] = IVs_with_const['Month_Name_August'].fillna(0)  # Replace NaN with 0
IVs_with_const['Month_Name_July'] = IVs_with_const['Month_Name_July'].fillna(0)
IVs_with_const['Month_Name_November'] = IVs_with_const['Month_Name_November'].fillna(0)
IVs_with_const['Month_Name_September'] = IVs_with_const['Month_Name_September'].fillna(0)
IVs_with_const['Month_Name_October'] = IVs_with_const['Month_Name_October'].fillna(0)
# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     8.063
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):           2.79e-29
# Time:                        20:46:50   Log-Likelihood:                -18536.
# No. Observations:               13134   AIC:                         3.712e+04
# Df Residuals:                   13108   BIC:                         3.732e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -7.134e-17      0.009  -8.23e-15      1.000      -0.017       0.017
# FOLLOWERS                       0.0172      0.009      1.877      0.061      -0.001       0.035
# FOLLOWING                      -0.0378      0.009     -4.261      0.000      -0.055      -0.020
# Tagged_Users_Count             -0.0011      0.009     -0.115      0.908      -0.019       0.017
# number_of_tags                 -0.0444      0.012     -3.830      0.000      -0.067      -0.022
# number_of_mentions             -0.0062      0.009     -0.666      0.505      -0.024       0.012
# Text_Length                     0.0527      0.012      4.554      0.000       0.030       0.075
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0059      0.009     -0.670      0.503      -0.023       0.011
# Post_Timing_Evening            -0.0006      0.011     -0.054      0.957      -0.022       0.020
# Post_Timing_Morning            -0.0093      0.010     -0.931      0.352      -0.029       0.010
# Post_Timing_Night              -0.0038      0.011     -0.342      0.732      -0.026       0.018
# Day_of_Week_Monday              0.0325      0.012      2.602      0.009       0.008       0.057
# Day_of_Week_Saturday           -0.0080      0.011     -0.715      0.474      -0.030       0.014
# Day_of_Week_Sunday             -0.0119      0.011     -1.050      0.294      -0.034       0.010
# Day_of_Week_Thursday           -0.0118      0.011     -1.039      0.299      -0.034       0.010
# Day_of_Week_Wednesday          -0.0053      0.011     -0.491      0.623      -0.026       0.016
# Day_of_Week_Tuesday            -0.0025      0.011     -0.230      0.818      -0.024       0.019
# Month_Name_August            -9.97e-18   2.41e-18     -4.136      0.000   -1.47e-17   -5.25e-18
# Month_Name_December            -0.0030      0.009     -0.341      0.733      -0.020       0.014
# Month_Name_February            -0.0015      0.009     -0.167      0.867      -0.018       0.016
# Month_Name_January             -0.0033      0.009     -0.379      0.705      -0.020       0.014
# Month_Name_July              1.379e-18      4e-18      0.345      0.730   -6.46e-18    9.22e-18
# Month_Name_March               -0.0033      0.009     -0.381      0.703      -0.020       0.014
# Month_Name_May                 -0.0353      0.010     -3.480      0.001      -0.055      -0.015
# Month_Name_November         -2.571e-18   2.72e-18     -0.946      0.344    -7.9e-18    2.76e-18
# Month_Name_October          -1.733e-18   1.93e-18     -0.897      0.370   -5.52e-18    2.05e-18
# Month_Name_September                 0          0        nan        nan           0           0
# Count_of_exclamation_markt      0.0399      0.009      4.461      0.000       0.022       0.057
# Count_of_question_mark          0.0054      0.009      0.573      0.567      -0.013       0.024
# keywords_for_engagement         0.0817      0.010      8.553      0.000       0.063       0.100
# emojis_for_engagement          -0.0203      0.009     -2.219      0.026      -0.038      -0.002
# ==============================================================================
# Omnibus:                    33389.308   Durbin-Watson:                   1.551
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        722947730.823
# Skew:                          28.409   Prob(JB):                         0.00
# Kurtosis:                    1150.967   Cond. No.                     1.23e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.9e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Regression for macro influencers

# %% [markdown]
# ### Regression Analysis for Predicting Likes (Macro Influencers)

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = macro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = macro_influencers[['LIKES']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     163.3
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:46:50   Log-Likelihood:                -66942.
# No. Observations:                6541   AIC:                         1.339e+05
# Df Residuals:                    6511   BIC:                         1.341e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         356.2042    296.741      1.200      0.230    -225.505     937.914
# FOLLOWERS                       0.0543      0.001     63.376      0.000       0.053       0.056
# FOLLOWING                      -0.3833      0.054     -7.149      0.000      -0.488      -0.278
# Tagged_Users_Count             50.6888     36.850      1.376      0.169     -21.549     122.927
# number_of_tags                -81.0876     14.488     -5.597      0.000    -109.489     -52.686
# number_of_mentions            -73.2309     58.572     -1.250      0.211    -188.051      41.589
# Text_Length                    -1.6286      0.742     -2.193      0.028      -3.084      -0.173
# TYPE(1 PHOTO,2 VIDEO)_video -1445.8289    285.467     -5.065      0.000   -2005.439    -886.219
# Post_Timing_Evening          -341.9780    233.738     -1.463      0.143    -800.182     116.226
# Post_Timing_Morning          -937.7213    297.090     -3.156      0.002   -1520.116    -355.326
# Post_Timing_Night            -282.1315    214.633     -1.314      0.189    -702.882     138.619
# Day_of_Week_Monday            133.0422    333.000      0.400      0.690    -519.747     785.832
# Day_of_Week_Saturday         -586.6675    304.133     -1.929      0.054   -1182.869       9.534
# Day_of_Week_Sunday           -392.9263    297.058     -1.323      0.186    -975.257     189.404
# Day_of_Week_Thursday          -22.8012    295.699     -0.077      0.939    -602.469     556.867
# Day_of_Week_Wednesday         -29.6051    330.147     -0.090      0.929    -676.802     617.592
# Day_of_Week_Tuesday          -297.0529    324.011     -0.917      0.359    -932.220     338.115
# Month_Name_August           -4.781e+04   1869.079    -25.580      0.000   -5.15e+04   -4.41e+04
# Month_Name_December          -5.28e+04   6815.579     -7.747      0.000   -6.62e+04   -3.94e+04
# Month_Name_February         -3.676e+04   2086.776    -17.618      0.000   -4.09e+04   -3.27e+04
# Month_Name_January          -4.227e+04   2044.441    -20.675      0.000   -4.63e+04   -3.83e+04
# Month_Name_July             -4.624e+04   2426.187    -19.061      0.000    -5.1e+04   -4.15e+04
# Month_Name_March             1.932e-10   1.65e-10      1.171      0.242    -1.3e-10    5.17e-10
# Month_Name_May              -1191.6251    401.652     -2.967      0.003   -1978.994    -404.256
# Month_Name_November         -4.539e+04   2422.022    -18.742      0.000   -5.01e+04   -4.06e+04
# Month_Name_October          -4.333e+04   1956.348    -22.148      0.000   -4.72e+04   -3.95e+04
# Month_Name_September        -4.449e+04   1572.461    -28.294      0.000   -4.76e+04   -4.14e+04
# Count_of_exclamation_markt   -122.5699     49.355     -2.483      0.013    -219.321     -25.818
# Count_of_question_mark         78.8535     35.924      2.195      0.028       8.431     149.276
# keywords_for_engagement       617.4792    111.322      5.547      0.000     399.251     835.707
# emojis_for_engagement        -215.3063    267.268     -0.806      0.421    -739.240     308.627
# ==============================================================================
# Omnibus:                     7879.631   Durbin-Watson:                   0.580
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1906591.352
# Skew:                           6.178   Prob(JB):                         0.00
# Kurtosis:                      85.722   Cond. No.                     1.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.65e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Standardized Regression Analysis for Predicting Likes (Macro Influencers)

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = macro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = macro_influencers[['LIKES']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)
# Fill missing values for specific columns
IVs_with_const['Month_Name_August'] = IVs_with_const['Month_Name_August'].fillna(0)  # Replace NaN with 0
IVs_with_const['Month_Name_July'] = IVs_with_const['Month_Name_July'].fillna(0)
IVs_with_const['Month_Name_November'] = IVs_with_const['Month_Name_November'].fillna(0)
IVs_with_const['Month_Name_September'] = IVs_with_const['Month_Name_September'].fillna(0)
IVs_with_const['Month_Name_October'] = IVs_with_const['Month_Name_October'].fillna(0)
IVs_with_const['Month_Name_March'] = IVs_with_const['Month_Name_March'].fillna(0)

# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  LIKES   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     163.3
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):               0.00
# Time:                        20:46:51   Log-Likelihood:                -7493.3
# No. Observations:                6541   AIC:                         1.505e+04
# Df Residuals:                    6511   BIC:                         1.525e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        8.713e-16      0.009   9.24e-14      1.000      -0.018       0.018
# FOLLOWERS                       0.9770      0.015     63.376      0.000       0.947       1.007
# FOLLOWING                      -0.0716      0.010     -7.149      0.000      -0.091      -0.052
# Tagged_Users_Count              0.0138      0.010      1.376      0.169      -0.006       0.034
# number_of_tags                 -0.0726      0.013     -5.597      0.000      -0.098      -0.047
# number_of_mentions             -0.0129      0.010     -1.250      0.211      -0.033       0.007
# Text_Length                    -0.0290      0.013     -2.193      0.028      -0.055      -0.003
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0490      0.010     -5.065      0.000      -0.068      -0.030
# Post_Timing_Evening            -0.0167      0.011     -1.463      0.143      -0.039       0.006
# Post_Timing_Morning            -0.0335      0.011     -3.156      0.002      -0.054      -0.013
# Post_Timing_Night              -0.0154      0.012     -1.314      0.189      -0.038       0.008
# Day_of_Week_Monday              0.0053      0.013      0.400      0.690      -0.021       0.031
# Day_of_Week_Saturday           -0.0234      0.012     -1.929      0.054      -0.047       0.000
# Day_of_Week_Sunday             -0.0163      0.012     -1.323      0.186      -0.041       0.008
# Day_of_Week_Thursday           -0.0010      0.012     -0.077      0.939      -0.025       0.023
# Day_of_Week_Wednesday          -0.0010      0.012     -0.090      0.929      -0.024       0.022
# Day_of_Week_Tuesday            -0.0109      0.012     -0.917      0.359      -0.034       0.012
# Month_Name_August              -0.2749      0.011    -25.580      0.000      -0.296      -0.254
# Month_Name_December            -0.0737      0.010     -7.747      0.000      -0.092      -0.055
# Month_Name_February            -0.1777      0.010    -17.618      0.000      -0.197      -0.158
# Month_Name_January             -0.2126      0.010    -20.675      0.000      -0.233      -0.192
# Month_Name_July                -0.1936      0.010    -19.061      0.000      -0.214      -0.174
# Month_Name_March             7.232e-18   1.98e-18      3.661      0.000    3.36e-18    1.11e-17
# Month_Name_May                 -0.0321      0.011     -2.967      0.003      -0.053      -0.011
# Month_Name_November            -0.1900      0.010    -18.742      0.000      -0.210      -0.170
# Month_Name_October             -0.2341      0.011    -22.148      0.000      -0.255      -0.213
# Month_Name_September           -0.3222      0.011    -28.294      0.000      -0.345      -0.300
# Count_of_exclamation_markt     -0.0248      0.010     -2.483      0.013      -0.044      -0.005
# Count_of_question_mark          0.0210      0.010      2.195      0.028       0.002       0.040
# keywords_for_engagement         0.0595      0.011      5.547      0.000       0.038       0.081
# emojis_for_engagement          -0.0077      0.010     -0.806      0.421      -0.026       0.011
# ==============================================================================
# Omnibus:                     7879.631   Durbin-Watson:                   0.580
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1906591.352
# Skew:                           6.178   Prob(JB):                         0.00
# Kurtosis:                      85.722   Cond. No.                     1.38e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.65e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Regression Analysis for Predicting Comments (Macro Influencers)

# %%
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# Define the dependent variable (DV) and independent variables (IVs)
IVs = macro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = macro_influencers[['COMMENTS']]

# Add a constant to the model (for the intercept)
IVs_with_const = sm.add_constant(IVs)

# Fit the linear regression model
model = sm.OLS(DV, IVs_with_const).fit()

# Get the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     30.66
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):          4.59e-157
# Time:                        20:46:53   Log-Likelihood:                -52297.
# No. Observations:                6541   AIC:                         1.047e+05
# Df Residuals:                    6511   BIC:                         1.049e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -3.4943     31.626     -0.110      0.912     -65.491      58.502
# FOLLOWERS                       0.0020   9.14e-05     22.282      0.000       0.002       0.002
# FOLLOWING                      -0.0196      0.006     -3.438      0.001      -0.031      -0.008
# Tagged_Users_Count             -7.8870      3.927     -2.008      0.045     -15.586      -0.188
# number_of_tags                 -8.5831      1.544     -5.559      0.000     -11.610      -5.556
# number_of_mentions             -6.2782      6.242     -1.006      0.315     -18.515       5.959
# Text_Length                    -0.1954      0.079     -2.469      0.014      -0.350      -0.040
# TYPE(1 PHOTO,2 VIDEO)_video   -43.5138     30.424     -1.430      0.153    -103.155      16.127
# Post_Timing_Evening           -84.2781     24.911     -3.383      0.001    -133.112     -35.444
# Post_Timing_Morning           -48.9538     31.663     -1.546      0.122    -111.023      13.116
# Post_Timing_Night             -88.7268     22.875     -3.879      0.000    -133.569     -43.885
# Day_of_Week_Monday             25.6234     35.490      0.722      0.470     -43.948      95.195
# Day_of_Week_Saturday          -86.9747     32.413     -2.683      0.007    -150.516     -23.434
# Day_of_Week_Sunday            -47.8028     31.659     -1.510      0.131    -109.865      14.260
# Day_of_Week_Thursday          -39.0155     31.515     -1.238      0.216    -100.794      22.763
# Day_of_Week_Wednesday         -43.3414     35.186     -1.232      0.218    -112.317      25.634
# Day_of_Week_Tuesday           -36.2737     34.532     -1.050      0.294    -103.967      31.420
# Month_Name_August           -2088.6590    199.199    -10.485      0.000   -2479.155   -1698.163
# Month_Name_December         -2024.1136    726.379     -2.787      0.005   -3448.055    -600.172
# Month_Name_February         -1695.5706    222.401     -7.624      0.000   -2131.549   -1259.592
# Month_Name_January          -1865.5110    217.889     -8.562      0.000   -2292.645   -1438.377
# Month_Name_July             -2219.0823    258.574     -8.582      0.000   -2725.972   -1712.192
# Month_Name_March             1.297e-11   1.76e-11      0.738      0.461   -2.15e-11    4.74e-11
# Month_Name_May               -107.8221     42.807     -2.519      0.012    -191.737     -23.907
# Month_Name_November         -2114.4220    258.130     -8.191      0.000   -2620.442   -1608.402
# Month_Name_October          -2074.9639    208.500     -9.952      0.000   -2483.693   -1666.235
# Month_Name_September        -2113.2977    167.587    -12.610      0.000   -2441.823   -1784.772
# Count_of_exclamation_markt     -8.7956      5.260     -1.672      0.095     -19.107       1.516
# Count_of_question_mark          8.2256      3.829      2.148      0.032       0.720      15.731
# keywords_for_engagement       195.4264     11.864     16.472      0.000     172.169     218.684
# emojis_for_engagement          13.4588     28.484      0.472      0.637     -42.380      69.298
# ==============================================================================
# Omnibus:                    13989.738   Durbin-Watson:                   0.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         65033282.815
# Skew:                          18.834   Prob(JB):                         0.00
# Kurtosis:                     490.031   Cond. No.                     1.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.65e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Standardized Regression Analysis for Predicting Comments (Micro Influencers)

# %%
from scipy.stats.mstats import zscore

# Define the dependent variable (DV) and independent variables (IVs)
IVs = macro_influencers[['FOLLOWERS', 'FOLLOWING', 'Tagged_Users_Count', 'number_of_tags', 'number_of_mentions', 'Text_Length', 'TYPE(1 PHOTO,2 VIDEO)_video',
                                            'Post_Timing_Evening', 'Post_Timing_Morning', 'Post_Timing_Night', 'Day_of_Week_Monday','Day_of_Week_Saturday',
                                            'Day_of_Week_Sunday', 'Day_of_Week_Thursday', 'Day_of_Week_Wednesday', 'Day_of_Week_Tuesday', 'Month_Name_August',
                                            'Month_Name_December', 'Month_Name_February', 'Month_Name_January', 'Month_Name_July', 'Month_Name_March',
                                            'Month_Name_May', 'Month_Name_November', 'Month_Name_October', 'Month_Name_September', 'Count_of_exclamation_markt','Count_of_question_mark', 'keywords_for_engagement', 'emojis_for_engagement']]
DV = macro_influencers[['COMMENTS']]

# Standardize the dependent variable (DV) and independent variables (IVs)
DV_standardized = zscore(DV)
IVs_standardized = zscore(IVs)

# Add a constant to the standardized independent variables
IVs_with_const = sm.add_constant(IVs_standardized)
# Fill missing values for specific columns

IVs_with_const['Month_Name_March'] = IVs_with_const['Month_Name_March'].fillna(0)

# Fit the OLS model using Statsmodels
standardized_model = sm.OLS(DV_standardized, IVs_with_const).fit()

# Get the summary of the regression results
print(standardized_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               COMMENTS   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     30.66
# Date:                Tue, 10 Dec 2024   Prob (F-statistic):          4.59e-157
# Time:                        20:46:53   Log-Likelihood:                -8862.6
# No. Observations:                6541   AIC:                         1.779e+04
# Df Residuals:                    6511   BIC:                         1.799e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        5.083e-16      0.012   4.37e-14      1.000      -0.023       0.023
# FOLLOWERS                       0.4235      0.019     22.282      0.000       0.386       0.461
# FOLLOWING                      -0.0425      0.012     -3.438      0.001      -0.067      -0.018
# Tagged_Users_Count             -0.0249      0.012     -2.008      0.045      -0.049      -0.001
# number_of_tags                 -0.0889      0.016     -5.559      0.000      -0.120      -0.058
# number_of_mentions             -0.0128      0.013     -1.006      0.315      -0.038       0.012
# Text_Length                    -0.0403      0.016     -2.469      0.014      -0.072      -0.008
# TYPE(1 PHOTO,2 VIDEO)_video    -0.0170      0.012     -1.430      0.153      -0.040       0.006
# Post_Timing_Evening            -0.0475      0.014     -3.383      0.001      -0.075      -0.020
# Post_Timing_Morning            -0.0203      0.013     -1.546      0.122      -0.046       0.005
# Post_Timing_Night              -0.0560      0.014     -3.879      0.000      -0.084      -0.028
# Day_of_Week_Monday              0.0117      0.016      0.722      0.470      -0.020       0.043
# Day_of_Week_Saturday           -0.0402      0.015     -2.683      0.007      -0.070      -0.011
# Day_of_Week_Sunday             -0.0230      0.015     -1.510      0.131      -0.053       0.007
# Day_of_Week_Thursday           -0.0188      0.015     -1.238      0.216      -0.049       0.011
# Day_of_Week_Wednesday          -0.0177      0.014     -1.232      0.218      -0.046       0.010
# Day_of_Week_Tuesday            -0.0154      0.015     -1.050      0.294      -0.044       0.013
# Month_Name_August              -0.1389      0.013    -10.485      0.000      -0.165      -0.113
# Month_Name_December            -0.0327      0.012     -2.787      0.005      -0.056      -0.010
# Month_Name_February            -0.0948      0.012     -7.624      0.000      -0.119      -0.070
# Month_Name_January             -0.1086      0.013     -8.562      0.000      -0.133      -0.084
# Month_Name_July                -0.1075      0.013     -8.582      0.000      -0.132      -0.083
# Month_Name_March              2.31e-18   2.44e-18      0.948      0.343   -2.46e-18    7.09e-18
# Month_Name_May                 -0.0336      0.013     -2.519      0.012      -0.060      -0.007
# Month_Name_November            -0.1024      0.013     -8.191      0.000      -0.127      -0.078
# Month_Name_October             -0.1297      0.013     -9.952      0.000      -0.155      -0.104
# Month_Name_September           -0.1770      0.014    -12.610      0.000      -0.205      -0.150
# Count_of_exclamation_markt     -0.0206      0.012     -1.672      0.095      -0.045       0.004
# Count_of_question_mark          0.0254      0.012      2.148      0.032       0.002       0.049
# keywords_for_engagement         0.2178      0.013     16.472      0.000       0.192       0.244
# emojis_for_engagement           0.0055      0.012      0.472      0.637      -0.017       0.029
# ==============================================================================
# Omnibus:                    13989.738   Durbin-Watson:                   0.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         65033282.815
# Skew:                          18.834   Prob(JB):                         0.00
# Kurtosis:                     490.031   Cond. No.                     1.38e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.65e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
